# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Initial Run Analysis: Deep Q-Learning on Cartpole

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9416228069143757, score: 32
# Scores: (min: 32, avg: 32, max: 32)
#
# Run: 2, exploration: 0.8955869907338783, score: 11
# Scores: (min: 11, avg: 21.5, max: 32)
#
# Run: 3, exploration: 0.8224322824348486, score: 18
# Scores: (min: 11, avg: 20.333333333333332, max: 32)
#
# Run: 4, exploration: 0.7477194593032545, score: 20
# Scores: (min: 11, avg: 20.25, max: 32)
#
# Run: 5, exploration: 0.7040696960536299, score: 13
# Scores: (min: 11, avg: 18.8, max: 32)
#
# Run: 6, exploration: 0.6730128848950395, score: 10
# Scores: (min: 10, avg: 17.333333333333332, max: 32)
#
# Run: 7, exploration: 0.5997278763867329, score: 24
# Scores: (min: 10, avg: 18.285714285714285, max: 32)
#
# Run: 8, exploration: 0.567555222460375, score: 12
# Scores: (min: 10, avg: 17.5, max: 32)
#
# Run: 9, exploration: 0.5425201222922789, score: 10
# Scores: (min: 10, avg: 16.666666666666668, max: 32)
#
# Run: 10, exploration: 0.5134164023722473, score: 12
# Scores: (min: 10, avg: 16.2, max: 32)
#
# Run: 11, exploration: 0.4883155414435353, score: 11
# Scores: (min: 10, avg: 15.727272727272727, max: 32)
#
# Run: 12, exploration: 0.47147873742168567, score: 8
# Scores: (min: 8, avg: 15.083333333333334, max: 32)
#
# Run: 13, exploration: 0.4529463432347434, score: 9
# Scores: (min: 8, avg: 14.615384615384615, max: 32)
#
# Run: 14, exploration: 0.43080185560799106, score: 11
# Scores: (min: 8, avg: 14.357142857142858, max: 32)
#
# Run: 15, exploration: 0.41386834584198684, score: 9
# Scores: (min: 8, avg: 14, max: 32)
#
# Run: 16, exploration: 0.3897078735047413, score: 13
# Scores: (min: 8, avg: 13.9375, max: 32)
#
# Run: 17, exploration: 0.37251769488706843, score: 10
# Scores: (min: 8, avg: 13.705882352941176, max: 32)
#
# Run: 18, exploration: 0.35608578229633, score: 10
# Scores: (min: 8, avg: 13.5, max: 32)
#
# Run: 19, exploration: 0.26227842021373715, score: 62
# Scores: (min: 8, avg: 16.05263157894737, max: 62)
#
# Run: 20, exploration: 0.2041345879004775, score: 51
# Scores: (min: 8, avg: 17.8, max: 62)
#
# Run: 21, exploration: 0.1473726336968319, score: 66
# Scores: (min: 8, avg: 20.095238095238095, max: 66)
#
# Run: 22, exploration: 0.11470197137452155, score: 51
# Scores: (min: 8, avg: 21.5, max: 66)
#
# Run: 23, exploration: 0.08750185146499175, score: 55
# Scores: (min: 8, avg: 22.956521739130434, max: 66)
#
# Run: 24, exploration: 0.06191698689958447, score: 70
# Scores: (min: 8, avg: 24.916666666666668, max: 70)
#
# Run: 25, exploration: 0.039435475429100995, score: 91
# Scores: (min: 8, avg: 27.56, max: 91)
#
# Run: 26, exploration: 0.026275840769466357, score: 82
# Scores: (min: 8, avg: 29.653846153846153, max: 91)
#
# Run: 27, exploration: 0.018407523107991184, score: 72
# Scores: (min: 8, avg: 31.22222222222222, max: 91)
#
# Run: 28, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 35.75, max: 158)
#
# Run: 29, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 40.93103448275862, max: 186)
#
# Run: 30, exploration: 0.01, score: 128
# Scores: (min: 8, avg: 43.833333333333336, max: 186)
#
# Run: 31, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 46.29032258064516, max: 186)
#
# Run: 32, exploration: 0.01, score: 123
# Scores: (min: 8, avg: 48.6875, max: 186)
#
# Run: 33, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 50.90909090909091, max: 186)
#
# Run: 34, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 55.26470588235294, max: 199)
#
# Run: 35, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 57.65714285714286, max: 199)
#
# Run: 36, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 61.05555555555556, max: 199)
#
# Run: 37, exploration: 0.01, score: 112
# Scores: (min: 8, avg: 62.432432432432435, max: 199)
#
# Run: 38, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 66.07894736842105, max: 201)
#
# Run: 39, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 69.23076923076923, max: 201)
#
# Run: 40, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 73.275, max: 231)
#
# Run: 41, exploration: 0.01, score: 242
# Scores: (min: 8, avg: 77.39024390243902, max: 242)
#
# Run: 42, exploration: 0.01, score: 238
# Scores: (min: 8, avg: 81.21428571428571, max: 242)
#
# Run: 43, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 83.88372093023256, max: 242)
#
# Run: 44, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 85.93181818181819, max: 242)
#
# Run: 45, exploration: 0.01, score: 271
# Scores: (min: 8, avg: 90.04444444444445, max: 271)
#
# Run: 46, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 92.73913043478261, max: 271)
#
# Run: 47, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 95.04255319148936, max: 271)
#
# Run: 48, exploration: 0.01, score: 304
# Scores: (min: 8, avg: 99.39583333333333, max: 304)
#
# Run: 49, exploration: 0.01, score: 221
# Scores: (min: 8, avg: 101.87755102040816, max: 304)
#
# Run: 50, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 104.08, max: 304)
#
# Run: 51, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 105.98039215686275, max: 304)
#
# Run: 52, exploration: 0.01, score: 319
# Scores: (min: 8, avg: 110.07692307692308, max: 319)
#
# Run: 53, exploration: 0.01, score: 246
# Scores: (min: 8, avg: 112.64150943396227, max: 319)
#
# Run: 54, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 114.25925925925925, max: 319)
#
# Run: 55, exploration: 0.01, score: 235
# Scores: (min: 8, avg: 116.45454545454545, max: 319)
#
# Run: 56, exploration: 0.01, score: 221
# Scores: (min: 8, avg: 118.32142857142857, max: 319)
#
# Run: 57, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 120.08771929824562, max: 319)
#
# Run: 58, exploration: 0.01, score: 281
# Scores: (min: 8, avg: 122.86206896551724, max: 319)
#
# Run: 59, exploration: 0.01, score: 324
# Scores: (min: 8, avg: 126.27118644067797, max: 324)
#
# Run: 60, exploration: 0.01, score: 239
# Scores: (min: 8, avg: 128.15, max: 324)
#
# Run: 61, exploration: 0.01, score: 271
# Scores: (min: 8, avg: 130.49180327868854, max: 324)
#
# Run: 62, exploration: 0.01, score: 459
# Scores: (min: 8, avg: 135.79032258064515, max: 459)
#
# Run: 63, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 137.0952380952381, max: 459)
#
# Run: 64, exploration: 0.01, score: 310
# Scores: (min: 8, avg: 139.796875, max: 459)
#
# Run: 65, exploration: 0.01, score: 230
# Scores: (min: 8, avg: 141.1846153846154, max: 459)
#
# Run: 66, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 141.6818181818182, max: 459)
#
# Run: 67, exploration: 0.01, score: 260
# Scores: (min: 8, avg: 143.44776119402985, max: 459)
#
# Run: 68, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 144.02941176470588, max: 459)
#
# Run: 69, exploration: 0.01, score: 215
# Scores: (min: 8, avg: 145.05797101449275, max: 459)
#
# Run: 70, exploration: 0.01, score: 252
# Scores: (min: 8, avg: 146.5857142857143, max: 459)
#
# Run: 71, exploration: 0.01, score: 192
# Scores: (min: 8, avg: 147.22535211267606, max: 459)
#
# Run: 72, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 148.02777777777777, max: 459)
#
# Run: 73, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 148.986301369863, max: 459)
#
# Run: 74, exploration: 0.01, score: 146
# Scores: (min: 8, avg: 148.94594594594594, max: 459)
#
# Run: 75, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 149.78666666666666, max: 459)
#
# Run: 76, exploration: 0.01, score: 366
# Scores: (min: 8, avg: 152.6315789473684, max: 459)
#
# Run: 77, exploration: 0.01, score: 241
# Scores: (min: 8, avg: 153.7792207792208, max: 459)
#
# Run: 78, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 153.9102564102564, max: 459)
#
# Run: 79, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 154.41772151898735, max: 459)
#
# Run: 80, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 155.075, max: 459)
#
# Run: 81, exploration: 0.01, score: 346
# Scores: (min: 8, avg: 157.4320987654321, max: 459)
#
# Run: 82, exploration: 0.01, score: 242
# Scores: (min: 8, avg: 158.46341463414635, max: 459)
#
# Run: 83, exploration: 0.01, score: 242
# Scores: (min: 8, avg: 159.46987951807228, max: 459)
#
# Run: 84, exploration: 0.01, score: 201
# Scores: (min: 8, avg: 159.96428571428572, max: 459)
#
# Run: 85, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 160.63529411764705, max: 459)
#
# Run: 86, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 164.58139534883722, max: 500)
#
# Run: 87, exploration: 0.01, score: 325
# Scores: (min: 8, avg: 166.42528735632183, max: 500)
#
# Run: 88, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 170.2159090909091, max: 500)
#
# Run: 89, exploration: 0.01, score: 248
# Scores: (min: 8, avg: 171.08988764044943, max: 500)
# Run: 90, exploration: 0.01, score: 364
# Scores: (min: 8, avg: 173.23333333333332, max: 500)
#
# Run: 91, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 173.13186813186815, max: 500)
#
# Run: 92, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 173.3586956521739, max: 500)
#
# Run: 93, exploration: 0.01, score: 164
# Scores: (min: 8, avg: 173.25806451612902, max: 500)
#
# Run: 94, exploration: 0.01, score: 238
# Scores: (min: 8, avg: 173.9468085106383, max: 500)
#
# Run: 95, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 174, max: 500)
#
# Run: 96, exploration: 0.01, score: 229
# Scores: (min: 8, avg: 174.57291666666666, max: 500)
#
# Run: 97, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 174.8556701030928, max: 500)
#
# Run: 98, exploration: 0.01, score: 394
# Scores: (min: 8, avg: 177.09183673469389, max: 500)
#
# Run: 99, exploration: 0.01, score: 272
# Scores: (min: 8, avg: 178.05050505050505, max: 500)
#
# Run: 100, exploration: 0.01, score: 240
# Scores: (min: 8, avg: 178.67, max: 500)
#
# Run: 101, exploration: 0.01, score: 240
# Scores: (min: 8, avg: 180.75, max: 500)
#
# Run: 102, exploration: 0.01, score: 169
# Scores: (min: 8, avg: 182.33, max: 500)
#
# Run: 103, exploration: 0.01, score: 356
# Scores: (min: 8, avg: 185.71, max: 500)
#
# Run: 104, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 187.51, max: 500)
#
# Run: 105, exploration: 0.01, score: 295
# Scores: (min: 8, avg: 190.33, max: 500)
#
# Run: 106, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 192.37, max: 500)
#
# Run: 107, exploration: 0.01, score: 319
# Scores: (min: 8, avg: 195.32, max: 500)
#
# Solved in 7 runs, 107 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# ## Reinforcement Learning Concepts in Cartpole
# ### What is the goal of the agent?
# - The agent’s objective is to **balance the pole on the cart for as long as possible** by selecting optimal left or right movements.
#
# ### What are the state values?
# - The Cartpole environment provides **four state values**:
#   1. **Cart Position**
#   2. **Cart Velocity**
#   3. **Pole Angle**
#   4. **Pole Angular Velocity**
#
# ### What are the possible actions?
# - The agent can take **two discrete actions**:
#   - **0:** Move Left
#   - **1:** Move Right
#
# ### What reinforcement algorithm is used?
# - The model uses **Deep Q-Learning (DQL)**, which improves standard **Q-learning** by:
#   - Using a **neural network** to approximate Q-values.
#   - Storing previous experiences in a **replay buffer** for training.
#   - **Decaying exploration** to shift from random actions to learned strategies.
#
# ---
#
# ## **Performance Overview**
# - **Total Runs:** 107
# - **Solved in:** 7 runs
# - **Exploration Rate:** Decayed from `1.0` to `0.01`
# - **Score Progression:**
#   - **Minimum Score:** 8
#   - **Maximum Score:** 500
#   - **Final Average Score:** 195.32
#
# ---
#
# ## **Observations**
# ### **Learning Progression**
# - **Early Runs (1–20):**
#   - The agent initially explores **randomly**, leading to inconsistent scores (8 to 66).
#   - Actions are **not yet optimized** due to high exploration (`>0.9`).
#
# - **Mid Runs (21–50):**
#   - As **exploration decays** (~0.1), the agent starts learning better strategies.
#   - Scores begin improving, averaging above **50**.
#
# - **Late Runs (51–107):**
#   - The model mostly **exploits learned policies** (`exploration ≈ 0.01`).
#   - Scores **stabilize between 200–500**, with some reaching the max **500**.
#
# ---
#
# ## **Key Takeaways**
# ### **How does experience replay work in this algorithm?**
# - **Experience replay stores past experiences** and randomly samples them during training.
# - This improves **learning efficiency** by avoiding **correlation between consecutive states**.
#
# ### **What is the effect of introducing a discount factor (`GAMMA`) for future rewards?**
# - A high `GAMMA = 0.95` allows the agent to **consider long-term rewards**, helping it balance the pole more effectively.
# - **Lower `GAMMA` values** would make the agent **focus more on immediate rewards** instead.
#
# ### **How are neural networks used in deep Q-learning?**
# - The model uses a **feedforward neural network** with two hidden layers:
#   - **Input:** State values `(cart position, velocity, angle, angular velocity)`.
#   - **Hidden Layers:** Two dense layers with **ReLU activation**.
#   - **Output:** Q-values for **each action** (left, right).
# - **Why is this efficient?**
#   - The neural network generalizes **Q-values for unseen states**, rather than storing a lookup table for every possible state.

# %% [markdown]
# ----

# %% [markdown]
# # Experiment 1: High Exploration Decay (`0.999`)

# %%
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.999  # Slower exploration decay, agent exploits faster

print("Running experiment with high exploration decay:", EXPLORATION_DECAY)
cartpole()
# Out:
# Running experiment with high exploration decay: 0.999
# Run: 1, exploration: 1.0, score: 10
# Scores: (min: 10, avg: 10, max: 10)
#
# Run: 2, exploration: 0.986090636999001, score: 24
# Scores: (min: 10, avg: 17, max: 24)
#
# Run: 3, exploration: 0.9694605362958227, score: 18
# Scores: (min: 10, avg: 17.333333333333332, max: 24)
#
# Run: 4, exploration: 0.9550199818235596, score: 16
# Scores: (min: 10, avg: 17, max: 24)
#
# Run: 5, exploration: 0.9342286880693633, score: 23
# Scores: (min: 10, avg: 18.2, max: 24)
#
# Run: 6, exploration: 0.9120631656822724, score: 25
# Scores: (min: 10, avg: 19.333333333333332, max: 25)
#
# Run: 7, exploration: 0.8895331192339416, score: 26
# Scores: (min: 10, avg: 20.285714285714285, max: 26)
#
# Run: 8, exploration: 0.8824417114557717, score: 9
# Scores: (min: 9, avg: 18.875, max: 26)
#
# Run: 9, exploration: 0.8675596164681794, score: 18
# Scores: (min: 9, avg: 18.77777777777778, max: 26)
#
# Run: 10, exploration: 0.8580640336044925, score: 12
# Scores: (min: 9, avg: 18.1, max: 26)
#
# Run: 11, exploration: 0.8461289094829862, score: 15
# Scores: (min: 9, avg: 17.818181818181817, max: 26)
#
# Run: 12, exploration: 0.831859218194368, score: 18
# Scores: (min: 9, avg: 17.833333333333332, max: 26)
#
# Run: 13, exploration: 0.7873207291459607, score: 56
# Scores: (min: 9, avg: 20.76923076923077, max: 56)
#
# Run: 14, exploration: 0.7732687760416481, score: 19
# Scores: (min: 9, avg: 20.642857142857142, max: 56)
#
# Run: 15, exploration: 0.7571914943525904, score: 22
# Scores: (min: 9, avg: 20.733333333333334, max: 56)
#
# Run: 16, exploration: 0.7355376118798452, score: 30
# Scores: (min: 9, avg: 21.3125, max: 56)
#
# Run: 17, exploration: 0.7267595445649057, score: 13
# Scores: (min: 9, avg: 20.823529411764707, max: 56)
#
# Run: 18, exploration: 0.6648431464805192, score: 90
# Scores: (min: 9, avg: 24.666666666666668, max: 90)
#
# Run: 19, exploration: 0.6555956018173954, score: 15
# Scores: (min: 9, avg: 24.157894736842106, max: 90)
#
# Run: 20, exploration: 0.6343035511776761, score: 34
# Scores: (min: 9, avg: 24.65, max: 90)
#
# Run: 21, exploration: 0.6009433131399452, score: 55
# Scores: (min: 9, avg: 26.095238095238095, max: 90)
#
# Run: 22, exploration: 0.5866853240299091, score: 25
# Scores: (min: 9, avg: 26.045454545454547, max: 90)
#
# Run: 23, exploration: 0.5536095095627305, score: 59
# Scores: (min: 9, avg: 27.47826086956522, max: 90)
#
# Run: 24, exploration: 0.5218760262931003, score: 60
# Scores: (min: 9, avg: 28.833333333333332, max: 90)
#
# Run: 25, exploration: 0.48706400382327686, score: 70
# Scores: (min: 9, avg: 30.48, max: 90)
#
# Run: 26, exploration: 0.44157439301269474, score: 99
# Scores: (min: 9, avg: 33.11538461538461, max: 99)
#
# Run: 27, exploration: 0.41460032563814003, score: 64
# Scores: (min: 9, avg: 34.25925925925926, max: 99)
#
# Run: 28, exploration: 0.38578451466104513, score: 73
# Scores: (min: 9, avg: 35.642857142857146, max: 99)
#
# Run: 29, exploration: 0.3483570387995002, score: 103
# Scores: (min: 9, avg: 37.96551724137931, max: 103)
#
# Run: 30, exploration: 0.32838884448265515, score: 60
# Scores: (min: 9, avg: 38.7, max: 103)
#
# Run: 31, exploration: 0.3022204989748846, score: 84
# Scores: (min: 9, avg: 40.16129032258065, max: 103)
#
# Run: 32, exploration: 0.25367890699899504, score: 176
# Scores: (min: 9, avg: 44.40625, max: 176)
#
# Run: 33, exploration: 0.2198614936868526, score: 144
# Scores: (min: 9, avg: 47.42424242424242, max: 176)
#
# Run: 34, exploration: 0.18846658486714196, score: 155
# Scores: (min: 9, avg: 50.588235294117645, max: 176)
#
# Run: 35, exploration: 0.1570916922361232, score: 183
# Scores: (min: 9, avg: 54.371428571428574, max: 183)
#
# Run: 36, exploration: 0.13238893993901227, score: 172
# Scores: (min: 9, avg: 57.638888888888886, max: 183)
#
# Run: 37, exploration: 0.11057057941158951, score: 181
# Scores: (min: 9, avg: 60.972972972972975, max: 183)
#
# Run: 38, exploration: 0.08688048724052432, score: 242
# Scores: (min: 9, avg: 65.73684210526316, max: 242)
#
# Run: 39, exploration: 0.06992511557881304, score: 218
# Scores: (min: 9, avg: 69.64102564102564, max: 242)
#
# Run: 40, exploration: 0.058051574441439185, score: 187
# Scores: (min: 9, avg: 72.575, max: 242)
#
# Run: 41, exploration: 0.047286708962080405, score: 206
# Scores: (min: 9, avg: 75.82926829268293, max: 242)
#
# Run: 42, exploration: 0.03871120894170404, score: 201
# Scores: (min: 9, avg: 78.80952380952381, max: 242)
#
# Run: 43, exploration: 0.031156429313642747, score: 218
# Scores: (min: 9, avg: 82.04651162790698, max: 242)
#
# Run: 44, exploration: 0.026099915150997823, score: 178
# Scores: (min: 9, avg: 84.22727272727273, max: 242)
#
# Run: 45, exploration: 0.021302629071520807, score: 204
# Scores: (min: 9, avg: 86.88888888888889, max: 242)
#
# Run: 46, exploration: 0.017214015809443074, score: 214
# Scores: (min: 9, avg: 89.65217391304348, max: 242)
#
# Run: 47, exploration: 0.013826877620138877, score: 220
# Scores: (min: 9, avg: 92.42553191489361, max: 242)
#
# Run: 48, exploration: 0.011217889511916658, score: 210
# Scores: (min: 9, avg: 94.875, max: 242)
#
# Run: 49, exploration: 0.01, score: 270
# Scores: (min: 9, avg: 98.44897959183673, max: 270)
#
# Run: 50, exploration: 0.01, score: 262
# Scores: (min: 9, avg: 101.72, max: 270)
#
# Run: 51, exploration: 0.01, score: 225
# Scores: (min: 9, avg: 104.13725490196079, max: 270)
#
# Run: 52, exploration: 0.01, score: 166
# Scores: (min: 9, avg: 105.32692307692308, max: 270)
#
# Run: 53, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 107.43396226415095, max: 270)
#
# Run: 54, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 108.53703703703704, max: 270)
#
# Run: 55, exploration: 0.01, score: 113
# Scores: (min: 9, avg: 108.61818181818182, max: 270)
#
# Run: 56, exploration: 0.01, score: 204
# Scores: (min: 9, avg: 110.32142857142857, max: 270)
#
# Run: 57, exploration: 0.01, score: 114
# Scores: (min: 9, avg: 110.3859649122807, max: 270)
#
# Run: 58, exploration: 0.01, score: 233
# Scores: (min: 9, avg: 112.5, max: 270)
#
# Run: 59, exploration: 0.01, score: 253
# Scores: (min: 9, avg: 114.88135593220339, max: 270)
#
# Run: 60, exploration: 0.01, score: 173
# Scores: (min: 9, avg: 115.85, max: 270)
#
# Run: 61, exploration: 0.01, score: 111
# Scores: (min: 9, avg: 115.77049180327869, max: 270)
#
# Run: 62, exploration: 0.01, score: 122
# Scores: (min: 9, avg: 115.87096774193549, max: 270)
#
# Run: 63, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 116.44444444444444, max: 270)
#
# Run: 64, exploration: 0.01, score: 255
# Scores: (min: 9, avg: 118.609375, max: 270)
#
# Run: 65, exploration: 0.01, score: 152
# Scores: (min: 9, avg: 119.12307692307692, max: 270)
#
# Run: 66, exploration: 0.01, score: 157
# Scores: (min: 9, avg: 119.6969696969697, max: 270)
#
# Run: 67, exploration: 0.01, score: 134
# Scores: (min: 9, avg: 119.91044776119404, max: 270)
#
# Run: 68, exploration: 0.01, score: 34
# Scores: (min: 9, avg: 118.6470588235294, max: 270)
#
# Run: 69, exploration: 0.01, score: 108
# Scores: (min: 9, avg: 118.4927536231884, max: 270)
#
# Run: 70, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 118.88571428571429, max: 270)
#
# Run: 71, exploration: 0.01, score: 146
# Scores: (min: 9, avg: 119.26760563380282, max: 270)
#
# Run: 72, exploration: 0.01, score: 162
# Scores: (min: 9, avg: 119.86111111111111, max: 270)
#
# Run: 73, exploration: 0.01, score: 178
# Scores: (min: 9, avg: 120.65753424657534, max: 270)
#
# Run: 74, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 121.63513513513513, max: 270)
#
# Run: 75, exploration: 0.01, score: 193
# Scores: (min: 9, avg: 122.58666666666667, max: 270)
#
# Run: 76, exploration: 0.01, score: 179
# Scores: (min: 9, avg: 123.32894736842105, max: 270)
#
# Run: 77, exploration: 0.01, score: 154
# Scores: (min: 9, avg: 123.72727272727273, max: 270)
#
# Run: 78, exploration: 0.01, score: 167
# Scores: (min: 9, avg: 124.28205128205128, max: 270)
#
# Run: 79, exploration: 0.01, score: 177
# Scores: (min: 9, avg: 124.9493670886076, max: 270)
#
# Run: 80, exploration: 0.01, score: 85
# Scores: (min: 9, avg: 124.45, max: 270)
#
# Run: 81, exploration: 0.01, score: 151
# Scores: (min: 9, avg: 124.77777777777777, max: 270)
#
# Run: 82, exploration: 0.01, score: 176
# Scores: (min: 9, avg: 125.40243902439025, max: 270)
#
# Run: 83, exploration: 0.01, score: 215
# Scores: (min: 9, avg: 126.48192771084338, max: 270)
#
# Run: 84, exploration: 0.01, score: 218
# Scores: (min: 9, avg: 127.57142857142857, max: 270)
#
# Run: 85, exploration: 0.01, score: 196
# Scores: (min: 9, avg: 128.3764705882353, max: 270)
# Run: 86, exploration: 0.01, score: 266
# Scores: (min: 9, avg: 129.97674418604652, max: 270)
#
# Run: 87, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 130.04597701149424, max: 270)
#
# Run: 88, exploration: 0.01, score: 246
# Scores: (min: 9, avg: 131.36363636363637, max: 270)
#
# Run: 89, exploration: 0.01, score: 149
# Scores: (min: 9, avg: 131.56179775280899, max: 270)
#
# Run: 90, exploration: 0.01, score: 172
# Scores: (min: 9, avg: 132.01111111111112, max: 270)
#
# Run: 91, exploration: 0.01, score: 174
# Scores: (min: 9, avg: 132.47252747252747, max: 270)
#
# Run: 92, exploration: 0.01, score: 140
# Scores: (min: 9, avg: 132.55434782608697, max: 270)
#
# Run: 93, exploration: 0.01, score: 209
# Scores: (min: 9, avg: 133.3763440860215, max: 270)
#
# Run: 94, exploration: 0.01, score: 164
# Scores: (min: 9, avg: 133.70212765957447, max: 270)
#
# Run: 95, exploration: 0.01, score: 195
# Scores: (min: 9, avg: 134.34736842105264, max: 270)
#
# Run: 96, exploration: 0.01, score: 180
# Scores: (min: 9, avg: 134.82291666666666, max: 270)
#
# Run: 97, exploration: 0.01, score: 197
# Scores: (min: 9, avg: 135.46391752577318, max: 270)
#
# Run: 98, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 135.64285714285714, max: 270)
#
# Run: 99, exploration: 0.01, score: 110
# Scores: (min: 9, avg: 135.3838383838384, max: 270)
#
# Run: 100, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 134.16, max: 270)
#
# Run: 101, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 134.17, max: 270)
#
# Run: 102, exploration: 0.01, score: 153
# Scores: (min: 9, avg: 135.46, max: 270)
#
# Run: 103, exploration: 0.01, score: 121
# Scores: (min: 9, avg: 136.49, max: 270)
#
# Run: 104, exploration: 0.01, score: 226
# Scores: (min: 9, avg: 138.59, max: 270)
#
# Run: 105, exploration: 0.01, score: 185
# Scores: (min: 9, avg: 140.21, max: 270)
#
# Run: 106, exploration: 0.01, score: 186
# Scores: (min: 9, avg: 141.82, max: 270)
#
# Run: 107, exploration: 0.01, score: 198
# Scores: (min: 9, avg: 143.54, max: 270)
#
# Run: 108, exploration: 0.01, score: 210
# Scores: (min: 11, avg: 145.55, max: 270)
#
# Run: 109, exploration: 0.01, score: 127
# Scores: (min: 11, avg: 146.64, max: 270)
#
# Run: 110, exploration: 0.01, score: 170
# Scores: (min: 11, avg: 148.22, max: 270)
#
# Run: 111, exploration: 0.01, score: 215
# Scores: (min: 11, avg: 150.22, max: 270)
#
# Run: 112, exploration: 0.01, score: 156
# Scores: (min: 11, avg: 151.6, max: 270)
#
# Run: 113, exploration: 0.01, score: 256
# Scores: (min: 11, avg: 153.6, max: 270)
#
# Run: 114, exploration: 0.01, score: 154
# Scores: (min: 11, avg: 154.95, max: 270)
#
# Run: 115, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 156.18, max: 270)
#
# Run: 116, exploration: 0.01, score: 212
# Scores: (min: 11, avg: 158, max: 270)
#
# Run: 117, exploration: 0.01, score: 152
# Scores: (min: 11, avg: 159.39, max: 270)
#
# Run: 118, exploration: 0.01, score: 191
# Scores: (min: 11, avg: 160.4, max: 270)
#
# Run: 119, exploration: 0.01, score: 164
# Scores: (min: 11, avg: 161.89, max: 270)
#
# Run: 120, exploration: 0.01, score: 159
# Scores: (min: 11, avg: 163.14, max: 270)
#
# Run: 121, exploration: 0.01, score: 181
# Scores: (min: 11, avg: 164.4, max: 270)
#
# Run: 122, exploration: 0.01, score: 139
# Scores: (min: 11, avg: 165.54, max: 270)
#
# Run: 123, exploration: 0.01, score: 142
# Scores: (min: 11, avg: 166.37, max: 270)
#
# Run: 124, exploration: 0.01, score: 247
# Scores: (min: 11, avg: 168.24, max: 270)
#
# Run: 125, exploration: 0.01, score: 190
# Scores: (min: 11, avg: 169.44, max: 270)
#
# Run: 126, exploration: 0.01, score: 176
# Scores: (min: 11, avg: 170.21, max: 270)
#
# Run: 127, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 171.22, max: 270)
#
# Run: 128, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 172.1, max: 270)
#
# Run: 129, exploration: 0.01, score: 222
# Scores: (min: 11, avg: 173.29, max: 270)
#
# Run: 130, exploration: 0.01, score: 141
# Scores: (min: 11, avg: 174.1, max: 270)
#
# Run: 131, exploration: 0.01, score: 143
# Scores: (min: 11, avg: 174.69, max: 270)
#
# Run: 132, exploration: 0.01, score: 133
# Scores: (min: 11, avg: 174.26, max: 270)
#
# Run: 133, exploration: 0.01, score: 109
# Scores: (min: 11, avg: 173.91, max: 270)
#
# Run: 134, exploration: 0.01, score: 118
# Scores: (min: 11, avg: 173.54, max: 270)
#
# Run: 135, exploration: 0.01, score: 171
# Scores: (min: 11, avg: 173.42, max: 270)
#
# Run: 136, exploration: 0.01, score: 315
# Scores: (min: 11, avg: 174.85, max: 315)
#
# Run: 137, exploration: 0.01, score: 221
# Scores: (min: 11, avg: 175.25, max: 315)
#
# Run: 138, exploration: 0.01, score: 353
# Scores: (min: 11, avg: 176.36, max: 353)
#
# Run: 139, exploration: 0.01, score: 181
# Scores: (min: 11, avg: 175.99, max: 353)
#
# Run: 140, exploration: 0.01, score: 222
# Scores: (min: 11, avg: 176.34, max: 353)
#
# Run: 141, exploration: 0.01, score: 170
# Scores: (min: 11, avg: 175.98, max: 353)
#
# Run: 142, exploration: 0.01, score: 181
# Scores: (min: 11, avg: 175.78, max: 353)
#
# Run: 143, exploration: 0.01, score: 205
# Scores: (min: 11, avg: 175.65, max: 353)
#
# Run: 144, exploration: 0.01, score: 191
# Scores: (min: 11, avg: 175.78, max: 353)
#
# Run: 145, exploration: 0.01, score: 80
# Scores: (min: 11, avg: 174.54, max: 353)
#
# Run: 146, exploration: 0.01, score: 15
# Scores: (min: 11, avg: 172.55, max: 353)
#
# Run: 147, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 170.46, max: 353)
#
# Run: 148, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 168.48, max: 353)
#
# Run: 149, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 165.9, max: 353)
#
# Run: 150, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 163.39, max: 353)
#
# Run: 151, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 161.24, max: 353)
#
# Run: 152, exploration: 0.01, score: 10
# Scores: (min: 10, avg: 159.68, max: 353)
#
# Run: 153, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 157.63, max: 353)
#
# Run: 154, exploration: 0.01, score: 11
# Scores: (min: 10, avg: 156.07, max: 353)
#
# Run: 155, exploration: 0.01, score: 13
# Scores: (min: 10, avg: 155.07, max: 353)
#
# Run: 156, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 153.15, max: 353)
#
# Run: 157, exploration: 0.01, score: 413
# Scores: (min: 10, avg: 156.14, max: 413)
#
# Run: 158, exploration: 0.01, score: 226
# Scores: (min: 10, avg: 156.07, max: 413)
#
# Run: 159, exploration: 0.01, score: 148
# Scores: (min: 10, avg: 155.02, max: 413)
#
# Run: 160, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 154.72, max: 413)
#
# Run: 161, exploration: 0.01, score: 250
# Scores: (min: 10, avg: 156.11, max: 413)
#
# Run: 162, exploration: 0.01, score: 163
# Scores: (min: 10, avg: 156.52, max: 413)
#
# Run: 163, exploration: 0.01, score: 139
# Scores: (min: 10, avg: 156.39, max: 413)
#
# Run: 164, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 155.33, max: 413)
#
# Run: 165, exploration: 0.01, score: 164
# Scores: (min: 10, avg: 155.45, max: 413)
#
# Run: 166, exploration: 0.01, score: 159
# Scores: (min: 10, avg: 155.47, max: 413)
#
# Run: 167, exploration: 0.01, score: 120
# Scores: (min: 10, avg: 155.33, max: 413)
#
# Run: 168, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 156.08, max: 413)
#
# Run: 169, exploration: 0.01, score: 217
# Scores: (min: 10, avg: 157.17, max: 413)
#
# Run: 170, exploration: 0.01, score: 171
# Scores: (min: 10, avg: 157.42, max: 413)
#
# Run: 171, exploration: 0.01, score: 101
# Scores: (min: 10, avg: 156.97, max: 413)
#
# Run: 172, exploration: 0.01, score: 305
# Scores: (min: 10, avg: 158.4, max: 413)
#
# Run: 173, exploration: 0.01, score: 84
# Scores: (min: 10, avg: 157.46, max: 413)
#
# Run: 174, exploration: 0.01, score: 263
# Scores: (min: 10, avg: 158.16, max: 413)
#
# Run: 175, exploration: 0.01, score: 119
# Scores: (min: 10, avg: 157.42, max: 413)
#
# Run: 176, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 157.54, max: 413)
#
# Run: 177, exploration: 0.01, score: 254
# Scores: (min: 10, avg: 158.54, max: 413)
#
# Run: 178, exploration: 0.01, score: 213
# Scores: (min: 10, avg: 159, max: 413)
#
# Run: 179, exploration: 0.01, score: 148
# Scores: (min: 10, avg: 158.71, max: 413)
#
# Run: 180, exploration: 0.01, score: 297
# Scores: (min: 10, avg: 160.83, max: 413)
#
# Run: 181, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 161.13, max: 413)
#
# Run: 182, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 161.18, max: 413)
#
# Run: 183, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 160.57, max: 413)
#
# Run: 184, exploration: 0.01, score: 265
# Scores: (min: 10, avg: 161.04, max: 413)
# Run: 185, exploration: 0.01, score: 156
# Scores: (min: 10, avg: 160.64, max: 413)
#
# Run: 186, exploration: 0.01, score: 79
# Scores: (min: 10, avg: 158.77, max: 413)
#
# Run: 187, exploration: 0.01, score: 255
# Scores: (min: 10, avg: 159.96, max: 413)
#
# Run: 188, exploration: 0.01, score: 316
# Scores: (min: 10, avg: 160.66, max: 413)
#
# Run: 189, exploration: 0.01, score: 187
# Scores: (min: 10, avg: 161.04, max: 413)
#
# Run: 190, exploration: 0.01, score: 208
# Scores: (min: 10, avg: 161.4, max: 413)
#
# Run: 191, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 161.46, max: 413)
#
# Run: 192, exploration: 0.01, score: 140
# Scores: (min: 10, avg: 161.46, max: 413)
#
# Run: 193, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 161.28, max: 413)
#
# Run: 194, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 161.18, max: 413)
#
# Run: 195, exploration: 0.01, score: 257
# Scores: (min: 10, avg: 161.8, max: 413)
#
# Run: 196, exploration: 0.01, score: 215
# Scores: (min: 10, avg: 162.15, max: 413)
#
# Run: 197, exploration: 0.01, score: 139
# Scores: (min: 10, avg: 161.57, max: 413)
#
# Run: 198, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 161.78, max: 413)
#
# Run: 199, exploration: 0.01, score: 441
# Scores: (min: 10, avg: 165.09, max: 441)
#
# Run: 200, exploration: 0.01, score: 214
# Scores: (min: 10, avg: 167.1, max: 441)
#
# Run: 201, exploration: 0.01, score: 251
# Scores: (min: 10, avg: 169.5, max: 441)
#
# Run: 202, exploration: 0.01, score: 79
# Scores: (min: 10, avg: 168.76, max: 441)
#
# Run: 203, exploration: 0.01, score: 321
# Scores: (min: 10, avg: 170.76, max: 441)
#
# Run: 204, exploration: 0.01, score: 378
# Scores: (min: 10, avg: 172.28, max: 441)
#
# Run: 205, exploration: 0.01, score: 156
# Scores: (min: 10, avg: 171.99, max: 441)
#
# Run: 206, exploration: 0.01, score: 273
# Scores: (min: 10, avg: 172.86, max: 441)
#
# Run: 207, exploration: 0.01, score: 227
# Scores: (min: 10, avg: 173.15, max: 441)
#
# Run: 208, exploration: 0.01, score: 140
# Scores: (min: 10, avg: 172.45, max: 441)
#
# Run: 209, exploration: 0.01, score: 93
# Scores: (min: 10, avg: 172.11, max: 441)
#
# Run: 210, exploration: 0.01, score: 63
# Scores: (min: 10, avg: 171.04, max: 441)
#
# Run: 211, exploration: 0.01, score: 330
# Scores: (min: 10, avg: 172.19, max: 441)
#
# Run: 212, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 172.06, max: 441)
#
# Run: 213, exploration: 0.01, score: 243
# Scores: (min: 10, avg: 171.93, max: 441)
#
# Run: 214, exploration: 0.01, score: 121
# Scores: (min: 10, avg: 171.6, max: 441)
#
# Run: 215, exploration: 0.01, score: 131
# Scores: (min: 10, avg: 171.46, max: 441)
#
# Run: 216, exploration: 0.01, score: 161
# Scores: (min: 10, avg: 170.95, max: 441)
#
# Run: 217, exploration: 0.01, score: 157
# Scores: (min: 10, avg: 171, max: 441)
#
# Run: 218, exploration: 0.01, score: 105
# Scores: (min: 10, avg: 170.14, max: 441)
#
# Run: 219, exploration: 0.01, score: 472
# Scores: (min: 10, avg: 173.22, max: 472)
#
# Run: 220, exploration: 0.01, score: 115
# Scores: (min: 10, avg: 172.78, max: 472)
#
# Run: 221, exploration: 0.01, score: 211
# Scores: (min: 10, avg: 173.08, max: 472)
#
# Run: 222, exploration: 0.01, score: 132
# Scores: (min: 10, avg: 173.01, max: 472)
#
# Run: 223, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 172.68, max: 472)
#
# Run: 224, exploration: 0.01, score: 139
# Scores: (min: 10, avg: 171.6, max: 472)
#
# Run: 225, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 174.7, max: 500)
#
# Run: 226, exploration: 0.01, score: 209
# Scores: (min: 10, avg: 175.03, max: 500)
#
# Run: 227, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 174.6, max: 500)
#
# Run: 228, exploration: 0.01, score: 317
# Scores: (min: 10, avg: 176.16, max: 500)
#
# Run: 229, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 175.49, max: 500)
#
# Run: 230, exploration: 0.01, score: 173
# Scores: (min: 10, avg: 175.81, max: 500)
#
# Run: 231, exploration: 0.01, score: 321
# Scores: (min: 10, avg: 177.59, max: 500)
#
# Run: 232, exploration: 0.01, score: 138
# Scores: (min: 10, avg: 177.64, max: 500)
#
# Run: 233, exploration: 0.01, score: 302
# Scores: (min: 10, avg: 179.57, max: 500)
#
# Run: 234, exploration: 0.01, score: 343
# Scores: (min: 10, avg: 181.82, max: 500)
#
# Run: 235, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 181.14, max: 500)
#
# Run: 236, exploration: 0.01, score: 160
# Scores: (min: 10, avg: 179.59, max: 500)
#
# Run: 237, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 182.38, max: 500)
#
# Run: 238, exploration: 0.01, score: 162
# Scores: (min: 10, avg: 180.47, max: 500)
#
# Run: 239, exploration: 0.01, score: 322
# Scores: (min: 10, avg: 181.88, max: 500)
#
# Run: 240, exploration: 0.01, score: 82
# Scores: (min: 10, avg: 180.48, max: 500)
#
# Run: 241, exploration: 0.01, score: 428
# Scores: (min: 10, avg: 183.06, max: 500)
#
# Run: 242, exploration: 0.01, score: 91
# Scores: (min: 10, avg: 182.16, max: 500)
#
# Run: 243, exploration: 0.01, score: 97
# Scores: (min: 10, avg: 181.08, max: 500)
#
# Run: 244, exploration: 0.01, score: 159
# Scores: (min: 10, avg: 180.76, max: 500)
#
# Run: 245, exploration: 0.01, score: 197
# Scores: (min: 10, avg: 181.93, max: 500)
#
# Run: 246, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 186.78, max: 500)
#
# Run: 247, exploration: 0.01, score: 169
# Scores: (min: 10, avg: 188.36, max: 500)
#
# Run: 248, exploration: 0.01, score: 154
# Scores: (min: 10, avg: 189.78, max: 500)
#
# Run: 249, exploration: 0.01, score: 134
# Scores: (min: 10, avg: 191, max: 500)
#
# Run: 250, exploration: 0.01, score: 162
# Scores: (min: 10, avg: 192.51, max: 500)
#
# Run: 251, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 197.41, max: 500)
#
# Solved in 151 runs, 251 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-9001733b40b4> in <module>
#       5
#       6 print("Running experiment with high exploration decay:", EXPLORATION_DECAY)
# ----> 7 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# ## **Objective**
# This experiment tested the effect of **higher exploration decay (`EXPLORATION_DECAY = 0.999`)**, meaning the agent transitioned **faster** from exploration (random actions) to exploitation (choosing optimal moves).
#
# ## **Performance Overview**
# - **Total Runs:** 251
# - **Solved in:** 151 runs (compared to **107 in the initial run**)
# - **Exploration Rate:** Decayed **faster** from `1.0` to `0.01`
# - **Score Progression:**
#   - **Minimum Score:** 9
#   - **Maximum Score:** 500
#   - **Final Average Score:** 197.41
#
# ---
#
# ## **Observations**
# ### **Effect on Early Learning (Runs 1–50)**
# - The agent **explored less** compared to the initial run.
# - Scores remained **low** early on, with a max score of **26** in the first 10 runs.
# - The **faster decay caused the agent to exploit too early**, reducing opportunities to explore better policies.
#
# ### **Effect on Mid to Late Learning (Runs 51–151)**
# - Performance **gradually improved**, with scores reaching **above 150** consistently after **100+ runs**.
# - The model **eventually learned optimal strategies**, reaching scores **above 400 and maxing out at 500**.
#
# ### **Overall Impact**
# - **Faster convergence to exploitation** led to **slower initial learning**.
# - **More stable performance in later runs**, but **took longer to solve Cartpole** than the original settings.
#
# ---
#
# ## **Key Takeaways**
# ### **How does experience replay work in this setting?**
# - Experience replay **still helped generalize learning**, but **early limited exploration** slowed down the discovery of effective strategies.
#
# ### **What was the effect of high exploration decay (`EXPLORATION_DECAY = 0.999`)?**
# - **Faster exploitation = slower early learning**
# - **Eventually stable** and **maxed out performance**, but **took longer to reach optimal play** (251 runs vs. 107 in the initial run).
# - The agent **failed to explore diverse strategies early**, leading to a delayed learning curve.
#
# ### **How does this compare to the initial run?**
# | Metric | Initial Run | High Exploration Decay Run |
# |--------|------------|---------------------------|
# | **Solved in** | 107 runs | **151 runs** (slower) |
# | **Max Score** | 500 | 500 |
# | **Final Avg. Score** | 195.32 | **197.41** (slightly better) |

# %% [markdown]
#   ----

# %% [markdown]
# # Experiment 2: Low Exploration Decay (More Exploration)

# %%
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.95  # Higher exploration time, takes longer to converge

print("Running experiment with low exploration decay:", EXPLORATION_DECAY)
cartpole()
# Out:
# Running experiment with low exploration decay: 0.95
# Run: 1, exploration: 0.5133420832795047, score: 33
# Scores: (min: 33, avg: 33, max: 33)
#
# Run: 2, exploration: 0.10467395472325498, score: 32
# Scores: (min: 32, avg: 32.5, max: 33)
#
# Run: 3, exploration: 0.0659706981778719, score: 10
# Scores: (min: 10, avg: 25, max: 33)
#
# Run: 4, exploration: 0.04376630903760433, score: 9
# Scores: (min: 9, avg: 21, max: 33)
#
# Run: 5, exploration: 0.027583690436774957, score: 10
# Scores: (min: 9, avg: 18.8, max: 33)
#
# Run: 6, exploration: 0.018299583806109226, score: 9
# Scores: (min: 9, avg: 17.166666666666668, max: 33)
#
# Run: 7, exploration: 0.011533301892006355, score: 10
# Scores: (min: 9, avg: 16.142857142857142, max: 33)
#
# Run: 8, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 15.375, max: 33)
#
# Run: 9, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 14.777777777777779, max: 33)
#
# Run: 10, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 14.3, max: 33)
#
# Run: 11, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 14, max: 33)
#
# Run: 12, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 13.666666666666666, max: 33)
#
# Run: 13, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 13.384615384615385, max: 33)
#
# Run: 14, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 13.071428571428571, max: 33)
#
# Run: 15, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 12.8, max: 33)
#
# Run: 16, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 12.625, max: 33)
#
# Run: 17, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 12.352941176470589, max: 33)
#
# Run: 18, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12.166666666666666, max: 33)
#
# Run: 19, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 12, max: 33)
#
# Run: 20, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.9, max: 33)
#
# Run: 21, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.761904761904763, max: 33)
#
# Run: 22, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.681818181818182, max: 33)
#
# Run: 23, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 11.652173913043478, max: 33)
#
# Run: 24, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.5, max: 33)
#
# Run: 25, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.44, max: 33)
#
# Run: 26, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.384615384615385, max: 33)
#
# Run: 27, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.333333333333334, max: 33)
#
# Run: 28, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.285714285714286, max: 33)
#
# Run: 29, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.241379310344827, max: 33)
#
# Run: 30, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 11.166666666666666, max: 33)
#
# Run: 31, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 11.064516129032258, max: 33)
#
# Run: 32, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 11.03125, max: 33)
#
# Run: 33, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.969696969696969, max: 33)
#
# Run: 34, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 10.882352941176471, max: 33)
#
# Run: 35, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 10.82857142857143, max: 33)
#
# Run: 36, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.805555555555555, max: 33)
#
# Run: 37, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 10.783783783783784, max: 33)
#
# Run: 38, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 11.657894736842104, max: 44)
#
# Run: 39, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 11.923076923076923, max: 44)
#
# Run: 40, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 12.6, max: 44)
#
# Run: 41, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 12.75609756097561, max: 44)
#
# Run: 42, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 13.5, max: 44)
#
# Run: 43, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 14.069767441860465, max: 44)
#
# Run: 44, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 15.068181818181818, max: 58)
#
# Run: 45, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 15.955555555555556, max: 58)
#
# Run: 46, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 17.58695652173913, max: 91)
#
# Run: 47, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 18.425531914893618, max: 91)
#
# Run: 48, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 19.041666666666668, max: 91)
#
# Run: 49, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 20.020408163265305, max: 91)
#
# Run: 50, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 20.54, max: 91)
#
# Run: 51, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 20.96078431372549, max: 91)
#
# Run: 52, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 21.365384615384617, max: 91)
#
# Run: 53, exploration: 0.01, score: 73
# Scores: (min: 8, avg: 22.339622641509433, max: 91)
#
# Run: 54, exploration: 0.01, score: 111
# Scores: (min: 8, avg: 23.98148148148148, max: 111)
#
# Run: 55, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 24.69090909090909, max: 111)
#
# Run: 56, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 24.982142857142858, max: 111)
#
# Run: 57, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 25.70175438596491, max: 111)
#
# Run: 58, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 26.086206896551722, max: 111)
#
# Run: 59, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 26.661016949152543, max: 111)
#
# Run: 60, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 26.916666666666668, max: 111)
#
# Run: 61, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 27.0327868852459, max: 111)
#
# Run: 62, exploration: 0.01, score: 36
# Scores: (min: 8, avg: 27.177419354838708, max: 111)
#
# Run: 63, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 27.285714285714285, max: 111)
#
# Run: 64, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 27.46875, max: 111)
#
# Run: 65, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 27.415384615384614, max: 111)
#
# Run: 66, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 28.37878787878788, max: 111)
#
# Run: 67, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 28.597014925373134, max: 111)
#
# Run: 68, exploration: 0.01, score: 65
# Scores: (min: 8, avg: 29.13235294117647, max: 111)
#
# Run: 69, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 29.043478260869566, max: 111)
#
# Run: 70, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 29.042857142857144, max: 111)
#
# Run: 71, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 29.183098591549296, max: 111)
#
# Run: 72, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 29.291666666666668, max: 111)
#
# Run: 73, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 29.10958904109589, max: 111)
#
# Run: 74, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 28.972972972972972, max: 111)
#
# Run: 75, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 29.186666666666667, max: 111)
#
# Run: 76, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 31.11842105263158, max: 176)
#
# Run: 77, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 31.766233766233768, max: 176)
#
# Run: 78, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 37.76923076923077, max: 500)
#
# Run: 79, exploration: 0.01, score: 457
# Scores: (min: 8, avg: 43.075949367088604, max: 500)
#
# Run: 80, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 48.7875, max: 500)
#
# Run: 81, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 54.358024691358025, max: 500)
#
# Run: 82, exploration: 0.01, score: 352
# Scores: (min: 8, avg: 57.98780487804878, max: 500)
#
# Run: 83, exploration: 0.01, score: 334
# Scores: (min: 8, avg: 61.31325301204819, max: 500)
#
# Run: 84, exploration: 0.01, score: 294
# Scores: (min: 8, avg: 64.08333333333333, max: 500)
#
# Run: 85, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 69.21176470588236, max: 500)
#
# Run: 86, exploration: 0.01, score: 261
# Scores: (min: 8, avg: 71.44186046511628, max: 500)
#
# Run: 87, exploration: 0.01, score: 271
# Scores: (min: 8, avg: 73.73563218390805, max: 500)
#
# Run: 88, exploration: 0.01, score: 270
# Scores: (min: 8, avg: 75.9659090909091, max: 500)
#
# Run: 89, exploration: 0.01, score: 233
# Scores: (min: 8, avg: 77.73033707865169, max: 500)
#
# Run: 90, exploration: 0.01, score: 323
# Scores: (min: 8, avg: 80.45555555555555, max: 500)
#
# Run: 91, exploration: 0.01, score: 224
# Scores: (min: 8, avg: 82.03296703296704, max: 500)
#
# Run: 92, exploration: 0.01, score: 424
# Scores: (min: 8, avg: 85.75, max: 500)
#
# Run: 93, exploration: 0.01, score: 404
# Scores: (min: 8, avg: 89.17204301075269, max: 500)
# Run: 94, exploration: 0.01, score: 410
# Scores: (min: 8, avg: 92.58510638297872, max: 500)
#
# Run: 95, exploration: 0.01, score: 196
# Scores: (min: 8, avg: 93.67368421052632, max: 500)
#
# Run: 96, exploration: 0.01, score: 259
# Scores: (min: 8, avg: 95.39583333333333, max: 500)
#
# Run: 97, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 96.25773195876289, max: 500)
#
# Run: 98, exploration: 0.01, score: 238
# Scores: (min: 8, avg: 97.70408163265306, max: 500)
#
# Run: 99, exploration: 0.01, score: 250
# Scores: (min: 8, avg: 99.24242424242425, max: 500)
#
# Run: 100, exploration: 0.01, score: 159
# Scores: (min: 8, avg: 99.84, max: 500)
#
# Run: 101, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 101.53, max: 500)
#
# Run: 102, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 102.18, max: 500)
#
# Run: 103, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 102.98, max: 500)
#
# Run: 104, exploration: 0.01, score: 291
# Scores: (min: 8, avg: 105.8, max: 500)
#
# Run: 105, exploration: 0.01, score: 270
# Scores: (min: 8, avg: 108.4, max: 500)
#
# Run: 106, exploration: 0.01, score: 230
# Scores: (min: 8, avg: 110.61, max: 500)
#
# Run: 107, exploration: 0.01, score: 228
# Scores: (min: 8, avg: 112.79, max: 500)
#
# Run: 108, exploration: 0.01, score: 397
# Scores: (min: 8, avg: 116.66, max: 500)
#
# Run: 109, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 118.49, max: 500)
#
# Run: 110, exploration: 0.01, score: 172
# Scores: (min: 8, avg: 120.11, max: 500)
#
# Run: 111, exploration: 0.01, score: 297
# Scores: (min: 8, avg: 122.97, max: 500)
#
# Run: 112, exploration: 0.01, score: 255
# Scores: (min: 8, avg: 125.42, max: 500)
#
# Run: 113, exploration: 0.01, score: 276
# Scores: (min: 8, avg: 128.08, max: 500)
#
# Run: 114, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 128.38, max: 500)
#
# Run: 115, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 130.15, max: 500)
#
# Run: 116, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 131.81, max: 500)
#
# Run: 117, exploration: 0.01, score: 223
# Scores: (min: 8, avg: 133.96, max: 500)
#
# Run: 118, exploration: 0.01, score: 153
# Scores: (min: 8, avg: 135.4, max: 500)
#
# Run: 119, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 136.78, max: 500)
#
# Run: 120, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 137.58, max: 500)
#
# Run: 121, exploration: 0.01, score: 81
# Scores: (min: 8, avg: 138.3, max: 500)
#
# Run: 122, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 140.15, max: 500)
#
# Run: 123, exploration: 0.01, score: 94
# Scores: (min: 8, avg: 140.98, max: 500)
#
# Run: 124, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 142.79, max: 500)
#
# Run: 125, exploration: 0.01, score: 310
# Scores: (min: 8, avg: 145.79, max: 500)
#
# Run: 126, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 146.21, max: 500)
#
# Run: 127, exploration: 0.01, score: 370
# Scores: (min: 8, avg: 149.81, max: 500)
#
# Run: 128, exploration: 0.01, score: 249
# Scores: (min: 8, avg: 152.2, max: 500)
#
# Run: 129, exploration: 0.01, score: 299
# Scores: (min: 8, avg: 155.09, max: 500)
#
# Run: 130, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 156.85, max: 500)
#
# Run: 131, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 161.77, max: 500)
#
# Run: 132, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 163.62, max: 500)
#
# Run: 133, exploration: 0.01, score: 311
# Scores: (min: 8, avg: 166.64, max: 500)
#
# Run: 134, exploration: 0.01, score: 233
# Scores: (min: 9, avg: 168.89, max: 500)
#
# Run: 135, exploration: 0.01, score: 311
# Scores: (min: 10, avg: 171.91, max: 500)
#
# Run: 136, exploration: 0.01, score: 114
# Scores: (min: 10, avg: 172.95, max: 500)
#
# Run: 137, exploration: 0.01, score: 270
# Scores: (min: 16, avg: 175.55, max: 500)
#
# Run: 138, exploration: 0.01, score: 291
# Scores: (min: 16, avg: 178.02, max: 500)
#
# Run: 139, exploration: 0.01, score: 72
# Scores: (min: 16, avg: 178.52, max: 500)
#
# Run: 140, exploration: 0.01, score: 242
# Scores: (min: 16, avg: 180.55, max: 500)
#
# Run: 141, exploration: 0.01, score: 168
# Scores: (min: 16, avg: 182.04, max: 500)
#
# Run: 142, exploration: 0.01, score: 464
# Scores: (min: 16, avg: 186.24, max: 500)
#
# Run: 143, exploration: 0.01, score: 188
# Scores: (min: 16, avg: 187.74, max: 500)
#
# Run: 144, exploration: 0.01, score: 141
# Scores: (min: 16, avg: 188.57, max: 500)
#
# Run: 145, exploration: 0.01, score: 151
# Scores: (min: 16, avg: 189.53, max: 500)
#
# Run: 146, exploration: 0.01, score: 337
# Scores: (min: 16, avg: 191.99, max: 500)
#
# Run: 147, exploration: 0.01, score: 473
# Scores: (min: 16, avg: 196.15, max: 500)
#
# Solved in 47 runs, 147 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-1d7042aac24f> in <module>
#       4
#       5 print("Running experiment with low exploration decay:", EXPLORATION_DECAY)
# ----> 6 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# ## **Objective**
# This experiment tested **a lower exploration decay (`EXPLORATION_DECAY = 0.95`)**, meaning the agent spent more time **exploring** before transitioning to **exploitation**. The goal was to analyze how extended exploration affects learning efficiency and final performance.
#
# ## **Performance Overview**
# - **Total Runs:** 147
# - **Solved in:** 47 runs (compared to **151 in Experiment 1** and **107 in the initial run**)
# - **Exploration Rate:** Decayed **slower**, maintaining higher randomness longer.
# - **Score Progression:**
#   - **Minimum Score:** 8
#   - **Maximum Score:** 500
#   - **Final Average Score:** 196.15
#
# ---
#
# ## **Observations**
# ### **Effect on Early Learning (Runs 1–50)**
# - The agent **continued exploring longer** compared to Experiment 1.
# - Scores remained **low (below 50) for a longer period**, but this ensured better policy discovery.
# - The slow decay allowed **more diverse experiences in experience replay**.
#
# ### **Effect on Mid to Late Learning (Runs 51–147)**
# - Performance **jumped significantly** after the **first 50 runs**.
# - The agent **maxed out at 500 points faster (by run 78)** compared to previous experiments.
# - Once exploration stabilized at `0.01`, **performance was consistently high**.
#
# ### **Overall Impact**
# - **Higher initial exploration slowed early learning** but led to **better long-term policies**.
# - **More consistent high scores once learning converged**.
# - **Fastest time to solve Cartpole (47 runs)** among all experiments.
#
# ---
#
# ## **Key Takeaways**
# ### **How does experience replay work in this setting?**
# - The **larger variety of early experiences** helped the model **generalize better**.
# - Unlike Experiment 1, where **early exploitation hindered learning**, this run had **a richer dataset**.
#
# ### **What was the effect of low exploration decay (`EXPLORATION_DECAY = 0.95`)?**
# - **Took longer to explore, but resulted in better final performance.**
# - **Avoided premature exploitation**, which can lock the agent into **suboptimal strategies**.
# - **Best balance** between exploration and learning efficiency among experiments so far.
#
# ### **How does this compare to previous runs?**
# | Metric | Initial Run | Exp. 1 (High Exp. Decay) | Exp. 2 (Low Exp. Decay) |
# |--------|------------|------------------|------------------|
# | **Solved in** | 107 runs | 151 runs | **47 runs** |
# | **Max Score** | 500 | 500 | 500 |
# | **Final Avg. Score** | 195.32 | 197.41 | **196.15** |

# %% [markdown]
# ----

# %% [markdown]
# # Experiment 3: Lower Discount Factor (Short-Term Focus)

# %%
GAMMA = 0.85  # Focuses more on immediate rewards

print("Running experiment with lower discount factor:", GAMMA)
cartpole()
# Out:
# Running experiment with lower discount factor: 0.85
# Run: 1, exploration: 1.0, score: 13
# Scores: (min: 13, avg: 13, max: 13)
#
# Run: 2, exploration: 0.029035463617657853, score: 76
# Scores: (min: 13, avg: 44.5, max: 76)
#
# Run: 3, exploration: 0.018299583806109226, score: 10
# Scores: (min: 10, avg: 33, max: 76)
#
# Run: 4, exploration: 0.01, score: 38
# Scores: (min: 10, avg: 34.25, max: 76)
#
# Run: 5, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 30.2, max: 76)
#
# Run: 6, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 29.666666666666668, max: 76)
#
# Run: 7, exploration: 0.01, score: 33
# Scores: (min: 10, avg: 30.142857142857142, max: 76)
#
# Run: 8, exploration: 0.01, score: 54
# Scores: (min: 10, avg: 33.125, max: 76)
#
# Run: 9, exploration: 0.01, score: 74
# Scores: (min: 10, avg: 37.666666666666664, max: 76)
#
# Run: 10, exploration: 0.01, score: 64
# Scores: (min: 10, avg: 40.3, max: 76)
#
# Run: 11, exploration: 0.01, score: 80
# Scores: (min: 10, avg: 43.90909090909091, max: 80)
#
# Run: 12, exploration: 0.01, score: 103
# Scores: (min: 10, avg: 48.833333333333336, max: 103)
#
# Run: 13, exploration: 0.01, score: 70
# Scores: (min: 10, avg: 50.46153846153846, max: 103)
#
# Run: 14, exploration: 0.01, score: 71
# Scores: (min: 10, avg: 51.92857142857143, max: 103)
#
# Run: 15, exploration: 0.01, score: 74
# Scores: (min: 10, avg: 53.4, max: 103)
#
# Run: 16, exploration: 0.01, score: 109
# Scores: (min: 10, avg: 56.875, max: 109)
#
# Run: 17, exploration: 0.01, score: 133
# Scores: (min: 10, avg: 61.35294117647059, max: 133)
#
# Run: 18, exploration: 0.01, score: 143
# Scores: (min: 10, avg: 65.88888888888889, max: 143)
#
# Run: 19, exploration: 0.01, score: 112
# Scores: (min: 10, avg: 68.3157894736842, max: 143)
#
# Run: 20, exploration: 0.01, score: 141
# Scores: (min: 10, avg: 71.95, max: 143)
#
# Run: 21, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 74.33333333333333, max: 143)
#
# Run: 22, exploration: 0.01, score: 113
# Scores: (min: 10, avg: 76.0909090909091, max: 143)
#
# Run: 23, exploration: 0.01, score: 219
# Scores: (min: 10, avg: 82.30434782608695, max: 219)
#
# Run: 24, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 86.41666666666667, max: 219)
#
# Run: 25, exploration: 0.01, score: 147
# Scores: (min: 10, avg: 88.84, max: 219)
#
# Run: 26, exploration: 0.01, score: 500
# Scores: (min: 10, avg: 104.65384615384616, max: 500)
#
# Run: 27, exploration: 0.01, score: 262
# Scores: (min: 10, avg: 110.48148148148148, max: 500)
#
# Run: 28, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 110.46428571428571, max: 500)
#
# Run: 29, exploration: 0.01, score: 300
# Scores: (min: 10, avg: 117, max: 500)
#
# Run: 30, exploration: 0.01, score: 127
# Scores: (min: 10, avg: 117.33333333333333, max: 500)
#
# Run: 31, exploration: 0.01, score: 155
# Scores: (min: 10, avg: 118.54838709677419, max: 500)
#
# Run: 32, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 118.65625, max: 500)
#
# Run: 33, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 118.3030303030303, max: 500)
#
# Run: 34, exploration: 0.01, score: 129
# Scores: (min: 10, avg: 118.61764705882354, max: 500)
#
# Run: 35, exploration: 0.01, score: 164
# Scores: (min: 10, avg: 119.91428571428571, max: 500)
#
# Run: 36, exploration: 0.01, score: 149
# Scores: (min: 10, avg: 120.72222222222223, max: 500)
#
# Run: 37, exploration: 0.01, score: 115
# Scores: (min: 10, avg: 120.56756756756756, max: 500)
#
# Run: 38, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 122.15789473684211, max: 500)
#
# Run: 39, exploration: 0.01, score: 182
# Scores: (min: 10, avg: 123.6923076923077, max: 500)
#
# Run: 40, exploration: 0.01, score: 141
# Scores: (min: 10, avg: 124.125, max: 500)
#
# Run: 41, exploration: 0.01, score: 236
# Scores: (min: 10, avg: 126.85365853658537, max: 500)
#
# Run: 42, exploration: 0.01, score: 166
# Scores: (min: 10, avg: 127.78571428571429, max: 500)
#
# Run: 43, exploration: 0.01, score: 122
# Scores: (min: 10, avg: 127.65116279069767, max: 500)
#
# Run: 44, exploration: 0.01, score: 89
# Scores: (min: 10, avg: 126.77272727272727, max: 500)
#
# Run: 45, exploration: 0.01, score: 142
# Scores: (min: 10, avg: 127.11111111111111, max: 500)
#
# Run: 46, exploration: 0.01, score: 17
# Scores: (min: 10, avg: 124.71739130434783, max: 500)
#
# Run: 47, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 122.46808510638297, max: 500)
#
# Run: 48, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 120.33333333333333, max: 500)
#
# Run: 49, exploration: 0.01, score: 19
# Scores: (min: 10, avg: 118.26530612244898, max: 500)
#
# Run: 50, exploration: 0.01, score: 248
# Scores: (min: 10, avg: 120.86, max: 500)
#
# Run: 51, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 118.72549019607843, max: 500)
#
# Run: 52, exploration: 0.01, score: 106
# Scores: (min: 10, avg: 118.48076923076923, max: 500)
#
# Run: 53, exploration: 0.01, score: 16
# Scores: (min: 10, avg: 116.54716981132076, max: 500)
#
# Run: 54, exploration: 0.01, score: 98
# Scores: (min: 10, avg: 116.20370370370371, max: 500)
#
# Run: 55, exploration: 0.01, score: 145
# Scores: (min: 10, avg: 116.72727272727273, max: 500)
#
# Run: 56, exploration: 0.01, score: 156
# Scores: (min: 10, avg: 117.42857142857143, max: 500)
#
# Run: 57, exploration: 0.01, score: 190
# Scores: (min: 10, avg: 118.70175438596492, max: 500)
#
# Run: 58, exploration: 0.01, score: 239
# Scores: (min: 10, avg: 120.77586206896552, max: 500)
#
# Run: 59, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 119.0677966101695, max: 500)
#
# Run: 60, exploration: 0.01, score: 34
# Scores: (min: 10, avg: 117.65, max: 500)
#
# Run: 61, exploration: 0.01, score: 12
# Scores: (min: 10, avg: 115.91803278688525, max: 500)
#
# Run: 62, exploration: 0.01, score: 119
# Scores: (min: 10, avg: 115.96774193548387, max: 500)
#
# Run: 63, exploration: 0.01, score: 243
# Scores: (min: 10, avg: 117.98412698412699, max: 500)
#
# Run: 64, exploration: 0.01, score: 167
# Scores: (min: 10, avg: 118.75, max: 500)
#
# Run: 65, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 119.16923076923077, max: 500)
#
# Run: 66, exploration: 0.01, score: 152
# Scores: (min: 10, avg: 119.66666666666667, max: 500)
#
# Run: 67, exploration: 0.01, score: 145
# Scores: (min: 10, avg: 120.04477611940298, max: 500)
#
# Run: 68, exploration: 0.01, score: 107
# Scores: (min: 10, avg: 119.8529411764706, max: 500)
#
# Run: 69, exploration: 0.01, score: 146
# Scores: (min: 10, avg: 120.23188405797102, max: 500)
#
# Run: 70, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 121.24285714285715, max: 500)
#
# Run: 71, exploration: 0.01, score: 400
# Scores: (min: 10, avg: 125.16901408450704, max: 500)
#
# Run: 72, exploration: 0.01, score: 294
# Scores: (min: 10, avg: 127.51388888888889, max: 500)
#
# Run: 73, exploration: 0.01, score: 151
# Scores: (min: 10, avg: 127.83561643835617, max: 500)
#
# Run: 74, exploration: 0.01, score: 95
# Scores: (min: 10, avg: 127.39189189189189, max: 500)
#
# Run: 75, exploration: 0.01, score: 139
# Scores: (min: 10, avg: 127.54666666666667, max: 500)
#
# Run: 76, exploration: 0.01, score: 209
# Scores: (min: 10, avg: 128.6184210526316, max: 500)
#
# Run: 77, exploration: 0.01, score: 227
# Scores: (min: 10, avg: 129.8961038961039, max: 500)
#
# Run: 78, exploration: 0.01, score: 106
# Scores: (min: 10, avg: 129.5897435897436, max: 500)
#
# Run: 79, exploration: 0.01, score: 200
# Scores: (min: 10, avg: 130.48101265822785, max: 500)
#
# Run: 80, exploration: 0.01, score: 262
# Scores: (min: 10, avg: 132.125, max: 500)
#
# Run: 81, exploration: 0.01, score: 153
# Scores: (min: 10, avg: 132.3827160493827, max: 500)
#
# Run: 82, exploration: 0.01, score: 246
# Scores: (min: 10, avg: 133.76829268292684, max: 500)
#
# Run: 83, exploration: 0.01, score: 181
# Scores: (min: 10, avg: 134.33734939759037, max: 500)
#
# Run: 84, exploration: 0.01, score: 270
# Scores: (min: 10, avg: 135.95238095238096, max: 500)
#
# Run: 85, exploration: 0.01, score: 28
# Scores: (min: 10, avg: 134.68235294117648, max: 500)
#
# Run: 86, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 133.27906976744185, max: 500)
#
# Run: 87, exploration: 0.01, score: 14
# Scores: (min: 10, avg: 131.90804597701148, max: 500)
#
# Run: 88, exploration: 0.01, score: 110
# Scores: (min: 10, avg: 131.6590909090909, max: 500)
#
# Run: 89, exploration: 0.01, score: 195
# Scores: (min: 10, avg: 132.37078651685394, max: 500)
#
# Run: 90, exploration: 0.01, score: 174
# Scores: (min: 10, avg: 132.83333333333334, max: 500)
#
# Run: 91, exploration: 0.01, score: 233
# Scores: (min: 10, avg: 133.93406593406593, max: 500)
# Run: 92, exploration: 0.01, score: 286
# Scores: (min: 10, avg: 135.58695652173913, max: 500)
#
# Run: 93, exploration: 0.01, score: 183
# Scores: (min: 10, avg: 136.09677419354838, max: 500)
#
# Run: 94, exploration: 0.01, score: 196
# Scores: (min: 10, avg: 136.7340425531915, max: 500)
#
# Run: 95, exploration: 0.01, score: 161
# Scores: (min: 10, avg: 136.98947368421054, max: 500)
#
# Run: 96, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 137.42708333333334, max: 500)
#
# Run: 97, exploration: 0.01, score: 352
# Scores: (min: 10, avg: 139.63917525773195, max: 500)
#
# Run: 98, exploration: 0.01, score: 164
# Scores: (min: 10, avg: 139.8877551020408, max: 500)
#
# Run: 99, exploration: 0.01, score: 139
# Scores: (min: 10, avg: 139.87878787878788, max: 500)
#
# Run: 100, exploration: 0.01, score: 185
# Scores: (min: 10, avg: 140.33, max: 500)
#
# Run: 101, exploration: 0.01, score: 119
# Scores: (min: 10, avg: 141.39, max: 500)
#
# Run: 102, exploration: 0.01, score: 225
# Scores: (min: 10, avg: 142.88, max: 500)
#
# Run: 103, exploration: 0.01, score: 100
# Scores: (min: 12, avg: 143.78, max: 500)
#
# Run: 104, exploration: 0.01, score: 235
# Scores: (min: 12, avg: 145.75, max: 500)
#
# Run: 105, exploration: 0.01, score: 101
# Scores: (min: 12, avg: 146.62, max: 500)
#
# Run: 106, exploration: 0.01, score: 53
# Scores: (min: 12, avg: 146.88, max: 500)
#
# Run: 107, exploration: 0.01, score: 191
# Scores: (min: 12, avg: 148.46, max: 500)
#
# Run: 108, exploration: 0.01, score: 254
# Scores: (min: 12, avg: 150.46, max: 500)
#
# Run: 109, exploration: 0.01, score: 179
# Scores: (min: 12, avg: 151.51, max: 500)
#
# Run: 110, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 155.87, max: 500)
#
# Run: 111, exploration: 0.01, score: 165
# Scores: (min: 12, avg: 156.72, max: 500)
#
# Run: 112, exploration: 0.01, score: 138
# Scores: (min: 12, avg: 157.07, max: 500)
#
# Run: 113, exploration: 0.01, score: 149
# Scores: (min: 12, avg: 157.86, max: 500)
#
# Run: 114, exploration: 0.01, score: 119
# Scores: (min: 12, avg: 158.34, max: 500)
#
# Run: 115, exploration: 0.01, score: 251
# Scores: (min: 12, avg: 160.11, max: 500)
#
# Run: 116, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 160.13, max: 500)
#
# Run: 117, exploration: 0.01, score: 230
# Scores: (min: 12, avg: 161.1, max: 500)
#
# Run: 118, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 164.67, max: 500)
#
# Run: 119, exploration: 0.01, score: 353
# Scores: (min: 12, avg: 167.08, max: 500)
#
# Run: 120, exploration: 0.01, score: 168
# Scores: (min: 12, avg: 167.35, max: 500)
#
# Run: 121, exploration: 0.01, score: 90
# Scores: (min: 12, avg: 167.03, max: 500)
#
# Run: 122, exploration: 0.01, score: 143
# Scores: (min: 12, avg: 167.33, max: 500)
#
# Run: 123, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 170.14, max: 500)
#
# Run: 124, exploration: 0.01, score: 265
# Scores: (min: 12, avg: 170.98, max: 500)
#
# Run: 125, exploration: 0.01, score: 99
# Scores: (min: 12, avg: 170.5, max: 500)
#
# Run: 126, exploration: 0.01, score: 233
# Scores: (min: 12, avg: 167.83, max: 500)
#
# Run: 127, exploration: 0.01, score: 142
# Scores: (min: 12, avg: 166.63, max: 500)
#
# Run: 128, exploration: 0.01, score: 412
# Scores: (min: 12, avg: 169.65, max: 500)
#
# Run: 129, exploration: 0.01, score: 150
# Scores: (min: 12, avg: 168.15, max: 500)
#
# Run: 130, exploration: 0.01, score: 258
# Scores: (min: 12, avg: 169.46, max: 500)
#
# Run: 131, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 168.98, max: 500)
#
# Run: 132, exploration: 0.01, score: 86
# Scores: (min: 12, avg: 168.62, max: 500)
#
# Run: 133, exploration: 0.01, score: 334
# Scores: (min: 12, avg: 170.89, max: 500)
#
# Run: 134, exploration: 0.01, score: 140
# Scores: (min: 12, avg: 171, max: 500)
#
# Run: 135, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 174.36, max: 500)
#
# Run: 136, exploration: 0.01, score: 45
# Scores: (min: 12, avg: 173.32, max: 500)
#
# Run: 137, exploration: 0.01, score: 97
# Scores: (min: 12, avg: 173.14, max: 500)
#
# Run: 138, exploration: 0.01, score: 64
# Scores: (min: 12, avg: 171.97, max: 500)
#
# Run: 139, exploration: 0.01, score: 45
# Scores: (min: 12, avg: 170.6, max: 500)
#
# Run: 140, exploration: 0.01, score: 57
# Scores: (min: 12, avg: 169.76, max: 500)
#
# Run: 141, exploration: 0.01, score: 133
# Scores: (min: 12, avg: 168.73, max: 500)
#
# Run: 142, exploration: 0.01, score: 159
# Scores: (min: 12, avg: 168.66, max: 500)
#
# Run: 143, exploration: 0.01, score: 216
# Scores: (min: 12, avg: 169.6, max: 500)
#
# Run: 144, exploration: 0.01, score: 167
# Scores: (min: 12, avg: 170.38, max: 500)
#
# Run: 145, exploration: 0.01, score: 193
# Scores: (min: 12, avg: 170.89, max: 500)
#
# Run: 146, exploration: 0.01, score: 206
# Scores: (min: 12, avg: 172.78, max: 500)
#
# Run: 147, exploration: 0.01, score: 233
# Scores: (min: 12, avg: 174.92, max: 500)
#
# Run: 148, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 175.87, max: 500)
#
# Run: 149, exploration: 0.01, score: 373
# Scores: (min: 12, avg: 179.41, max: 500)
#
# Run: 150, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 178.23, max: 500)
#
# Run: 151, exploration: 0.01, score: 16
# Scores: (min: 12, avg: 178.27, max: 500)
#
# Run: 152, exploration: 0.01, score: 143
# Scores: (min: 12, avg: 178.64, max: 500)
#
# Run: 153, exploration: 0.01, score: 176
# Scores: (min: 12, avg: 180.24, max: 500)
#
# Run: 154, exploration: 0.01, score: 475
# Scores: (min: 12, avg: 184.01, max: 500)
#
# Run: 155, exploration: 0.01, score: 414
# Scores: (min: 12, avg: 186.7, max: 500)
#
# Run: 156, exploration: 0.01, score: 412
# Scores: (min: 12, avg: 189.26, max: 500)
#
# Run: 157, exploration: 0.01, score: 71
# Scores: (min: 12, avg: 188.07, max: 500)
#
# Run: 158, exploration: 0.01, score: 151
# Scores: (min: 12, avg: 187.19, max: 500)
#
# Run: 159, exploration: 0.01, score: 123
# Scores: (min: 12, avg: 188.22, max: 500)
#
# Run: 160, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 188, max: 500)
#
# Run: 161, exploration: 0.01, score: 77
# Scores: (min: 12, avg: 188.65, max: 500)
#
# Run: 162, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 192.46, max: 500)
#
# Run: 163, exploration: 0.01, score: 352
# Scores: (min: 12, avg: 193.55, max: 500)
#
# Run: 164, exploration: 0.01, score: 318
# Scores: (min: 12, avg: 195.06, max: 500)
#
# Solved in 64 runs, 164 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-df6aa11194ab> in <module>
#       2
#       3 print("Running experiment with lower discount factor:", GAMMA)
# ----> 4 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# ## **Objective**
# This experiment tested **a lower discount factor (`GAMMA = 0.85`)**, prioritizing **short-term rewards** over long-term stability. The goal was to evaluate how this change impacts learning speed, policy formation, and final performance.
#
# ## **Performance Overview**
# - **Total Runs:** 164
# - **Solved in:** 64 runs
# - **Discount Factor (`GAMMA`)**: Reduced from **0.95** to **0.85**
# - **Score Progression:**
#   - **Minimum Score:** 10
#   - **Maximum Score:** 500
#   - **Final Average Score:** 195.06
#
# ---
#
# ## **Observations**
# ### **Early Learning Phase (Runs 1–20)**
# - The agent **prioritized immediate rewards**, leading to **unstable early performance**.
# - **Initial scores fluctuated significantly**, indicating difficulty in identifying long-term strategies.
# - **Performance increased slower than in Experiment 2**.
#
# ### **Mid-Learning Phase (Runs 21–80)**
# - The agent **started achieving high scores (~100-200 range) earlier** than in previous experiments.
# - **Solved at 64 runs**, which is **faster than Experiment 1 (151 runs)** but **slower than Experiment 2 (47 runs)**.
# - **Policy formation was more aggressive**, favoring short-term gains.
#
# ### **Late Learning Phase (Runs 81–164)**
# - Scores **stabilized near 200** but remained slightly lower than those in **Experiment 2**.
# - **More volatile end performance** compared to higher discount factor runs.
# - **Achieved 500-point max score at a slower rate** than in Experiment 2.
#
# ---
#
# ## **Key Takeaways**
# ### **How does a lower discount factor (`GAMMA = 0.85`) affect learning?**
# - **Faster short-term learning**, but at the cost of **less stable long-term performance**.
# - **More reactive decision-making**, leading to **less optimal long-term strategies**.
# - **Lower maximum average score**, meaning the model **did not generalize as well**.
#
# ### **How does this compare to previous experiments?**
# | Metric | Initial Run | Exp. 1 (High Exp. Decay) | Exp. 2 (Low Exp. Decay) | Exp. 3 (Low GAMMA) |
# |--------|------------|------------------|------------------|------------------|
# | **Solved in** | 107 runs | 151 runs | **47 runs** | 64 runs |
# | **Max Score** | 500 | 500 | 500 | 500 |
# | **Final Avg. Score** | 195.32 | 197.41 | **196.15** | 195.06 |
# | **Strategy** | Balanced | Faster learning | Best exploration-exploitation | Short-term rewards |

# %% [markdown]
#   ----

# %% [markdown]
# # Experiment 4: Lower Learning Rate (More Stability)

# %%
LEARNING_RATE = 0.0001  # Reduces update magnitude, stabilizes learning

print("Running experiment with lower learning rate:", LEARNING_RATE)
cartpole()
# Out:
# Running experiment with lower learning rate: 0.0001
# Run: 1, exploration: 0.7737809374999999, score: 25
# Scores: (min: 25, avg: 25, max: 25)
#
# Run: 2, exploration: 0.30735686772502346, score: 19
# Scores: (min: 19, avg: 22, max: 25)
#
# Run: 3, exploration: 0.18402591023557577, score: 11
# Scores: (min: 11, avg: 18.333333333333332, max: 25)
#
# Run: 4, exploration: 0.11598222130000553, score: 10
# Scores: (min: 10, avg: 16.25, max: 25)
#
# Run: 5, exploration: 0.0694428401872336, score: 11
# Scores: (min: 10, avg: 15.2, max: 25)
#
# Run: 6, exploration: 0.04376630903760433, score: 10
# Scores: (min: 10, avg: 14.333333333333334, max: 25)
#
# Run: 7, exploration: 0.029035463617657853, score: 9
# Scores: (min: 9, avg: 13.571428571428571, max: 25)
#
# Run: 8, exploration: 0.019262719795904448, score: 9
# Scores: (min: 9, avg: 13, max: 25)
#
# Run: 9, exploration: 0.012779281874799287, score: 9
# Scores: (min: 9, avg: 12.555555555555555, max: 25)
#
# Run: 10, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 12.3, max: 25)
#
# Run: 11, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 12, max: 25)
#
# Run: 12, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 11.916666666666666, max: 25)
#
# Run: 13, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 12.307692307692308, max: 25)
#
# Run: 14, exploration: 0.01, score: 55
# Scores: (min: 9, avg: 15.357142857142858, max: 55)
#
# Run: 15, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 17.2, max: 55)
#
# Run: 16, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 18.8125, max: 55)
#
# Run: 17, exploration: 0.01, score: 51
# Scores: (min: 9, avg: 20.705882352941178, max: 55)
#
# Run: 18, exploration: 0.01, score: 43
# Scores: (min: 9, avg: 21.944444444444443, max: 55)
#
# Run: 19, exploration: 0.01, score: 46
# Scores: (min: 9, avg: 23.210526315789473, max: 55)
#
# Run: 20, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 22.85, max: 55)
#
# Run: 21, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 22.428571428571427, max: 55)
#
# Run: 22, exploration: 0.01, score: 15
# Scores: (min: 9, avg: 22.09090909090909, max: 55)
#
# Run: 23, exploration: 0.01, score: 22
# Scores: (min: 9, avg: 22.08695652173913, max: 55)
#
# Run: 24, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 21.625, max: 55)
#
# Run: 25, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 21.12, max: 55)
#
# Run: 26, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 20.76923076923077, max: 55)
#
# Run: 27, exploration: 0.01, score: 21
# Scores: (min: 9, avg: 20.77777777777778, max: 55)
#
# Run: 28, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 20.357142857142858, max: 55)
#
# Run: 29, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 20.03448275862069, max: 55)
#
# Run: 30, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 19.833333333333332, max: 55)
#
# Run: 31, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 19.483870967741936, max: 55)
#
# Run: 32, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 19.1875, max: 55)
#
# Run: 33, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 18.87878787878788, max: 55)
#
# Run: 34, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 18.558823529411764, max: 55)
#
# Run: 35, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 19.2, max: 55)
#
# Run: 36, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 19.333333333333332, max: 55)
#
# Run: 37, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 19.594594594594593, max: 55)
#
# Run: 38, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 19.710526315789473, max: 55)
#
# Run: 39, exploration: 0.01, score: 21
# Scores: (min: 8, avg: 19.743589743589745, max: 55)
#
# Run: 40, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 19.65, max: 55)
#
# Run: 41, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 19.5609756097561, max: 55)
#
# Run: 42, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 19.428571428571427, max: 55)
#
# Run: 43, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.3953488372093, max: 55)
#
# Run: 44, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 19.59090909090909, max: 55)
#
# Run: 45, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 19.755555555555556, max: 55)
#
# Run: 46, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 19.67391304347826, max: 55)
#
# Run: 47, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 19.574468085106382, max: 55)
#
# Run: 48, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.541666666666668, max: 55)
#
# Run: 49, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 19.79591836734694, max: 55)
#
# Run: 50, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 19.76, max: 55)
#
# Run: 51, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.627450980392158, max: 55)
#
# Run: 52, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 19.5, max: 55)
#
# Run: 53, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 19.49056603773585, max: 55)
#
# Run: 54, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 19.5, max: 55)
#
# Run: 55, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 19.78181818181818, max: 55)
#
# Run: 56, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 19.892857142857142, max: 55)
#
# Run: 57, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 20.017543859649123, max: 55)
#
# Run: 58, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 20.137931034482758, max: 55)
#
# Run: 59, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 20.661016949152543, max: 55)
#
# Run: 60, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 21.3, max: 59)
#
# Run: 61, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 21.491803278688526, max: 59)
#
# Run: 62, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 22, max: 59)
#
# Run: 63, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 22.11111111111111, max: 59)
#
# Run: 64, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 22.875, max: 71)
#
# Run: 65, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 23.323076923076922, max: 71)
#
# Run: 66, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 23.439393939393938, max: 71)
#
# Run: 67, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 24.074626865671643, max: 71)
#
# Run: 68, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 25.073529411764707, max: 92)
#
# Run: 69, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 25.72463768115942, max: 92)
#
# Run: 70, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 26.042857142857144, max: 92)
#
# Run: 71, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 26.225352112676056, max: 92)
#
# Run: 72, exploration: 0.01, score: 37
# Scores: (min: 8, avg: 26.375, max: 92)
#
# Run: 73, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 26.698630136986303, max: 92)
#
# Run: 74, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 27.2027027027027, max: 92)
#
# Run: 75, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 27.826666666666668, max: 92)
#
# Run: 76, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 28.157894736842106, max: 92)
#
# Run: 77, exploration: 0.01, score: 95
# Scores: (min: 8, avg: 29.025974025974026, max: 95)
#
# Run: 78, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 29.71794871794872, max: 95)
#
# Run: 79, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 30.29113924050633, max: 95)
#
# Run: 80, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 31.0625, max: 95)
#
# Run: 81, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 31.604938271604937, max: 95)
#
# Run: 82, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 31.975609756097562, max: 95)
#
# Run: 83, exploration: 0.01, score: 135
# Scores: (min: 8, avg: 33.21686746987952, max: 135)
#
# Run: 84, exploration: 0.01, score: 52
# Scores: (min: 8, avg: 33.44047619047619, max: 135)
#
# Run: 85, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 33.43529411764706, max: 135)
#
# Run: 86, exploration: 0.01, score: 82
# Scores: (min: 8, avg: 34, max: 135)
#
# Run: 87, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 34.310344827586206, max: 135)
#
# Run: 88, exploration: 0.01, score: 46
# Scores: (min: 8, avg: 34.44318181818182, max: 135)
#
# Run: 89, exploration: 0.01, score: 92
# Scores: (min: 8, avg: 35.08988764044944, max: 135)
#
# Run: 90, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 35.15555555555556, max: 135)
#
# Run: 91, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 36.07692307692308, max: 135)
#
# Run: 92, exploration: 0.01, score: 67
# Scores: (min: 8, avg: 36.41304347826087, max: 135)
#
# Run: 93, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 36.913978494623656, max: 135)
# Run: 94, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 36.851063829787236, max: 135)
#
# Run: 95, exploration: 0.01, score: 76
# Scores: (min: 8, avg: 37.26315789473684, max: 135)
#
# Run: 96, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 37.75, max: 135)
#
# Run: 97, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 38.91752577319588, max: 151)
#
# Run: 98, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 39.11224489795919, max: 151)
#
# Run: 99, exploration: 0.01, score: 70
# Scores: (min: 8, avg: 39.42424242424242, max: 151)
#
# Run: 100, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 39.74, max: 151)
#
# Run: 101, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 40.15, max: 151)
#
# Run: 102, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 40.84, max: 151)
#
# Run: 103, exploration: 0.01, score: 77
# Scores: (min: 8, avg: 41.5, max: 151)
#
# Run: 104, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 41.91, max: 151)
#
# Run: 105, exploration: 0.01, score: 110
# Scores: (min: 8, avg: 42.9, max: 151)
#
# Run: 106, exploration: 0.01, score: 74
# Scores: (min: 8, avg: 43.54, max: 151)
#
# Run: 107, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 45.45, max: 200)
#
# Run: 108, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 47.4, max: 204)
#
# Run: 109, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 48.93, max: 204)
#
# Run: 110, exploration: 0.01, score: 109
# Scores: (min: 8, avg: 49.92, max: 204)
#
# Run: 111, exploration: 0.01, score: 155
# Scores: (min: 8, avg: 51.38, max: 204)
#
# Run: 112, exploration: 0.01, score: 86
# Scores: (min: 8, avg: 52.13, max: 204)
#
# Run: 113, exploration: 0.01, score: 223
# Scores: (min: 8, avg: 54.19, max: 223)
#
# Run: 114, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 55.11, max: 223)
#
# Run: 115, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 56.44, max: 223)
#
# Run: 116, exploration: 0.01, score: 230
# Scores: (min: 8, avg: 58.31, max: 230)
#
# Run: 117, exploration: 0.01, score: 402
# Scores: (min: 8, avg: 61.82, max: 402)
#
# Run: 118, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 66.39, max: 500)
#
# Run: 119, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 68.1, max: 500)
#
# Run: 120, exploration: 0.01, score: 264
# Scores: (min: 8, avg: 70.58, max: 500)
#
# Run: 121, exploration: 0.01, score: 338
# Scores: (min: 8, avg: 73.82, max: 500)
#
# Run: 122, exploration: 0.01, score: 368
# Scores: (min: 8, avg: 77.35, max: 500)
#
# Run: 123, exploration: 0.01, score: 215
# Scores: (min: 8, avg: 79.28, max: 500)
#
# Run: 124, exploration: 0.01, score: 272
# Scores: (min: 8, avg: 81.89, max: 500)
#
# Run: 125, exploration: 0.01, score: 290
# Scores: (min: 8, avg: 84.7, max: 500)
#
# Run: 126, exploration: 0.01, score: 334
# Scores: (min: 8, avg: 87.92, max: 500)
#
# Run: 127, exploration: 0.01, score: 319
# Scores: (min: 8, avg: 90.9, max: 500)
#
# Run: 128, exploration: 0.01, score: 359
# Scores: (min: 8, avg: 94.4, max: 500)
#
# Run: 129, exploration: 0.01, score: 229
# Scores: (min: 8, avg: 96.58, max: 500)
#
# Run: 130, exploration: 0.01, score: 288
# Scores: (min: 8, avg: 99.32, max: 500)
#
# Run: 131, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 104.23, max: 500)
#
# Run: 132, exploration: 0.01, score: 404
# Scores: (min: 8, avg: 108.17, max: 500)
#
# Run: 133, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 110.1, max: 500)
#
# Run: 134, exploration: 0.01, score: 279
# Scores: (min: 13, avg: 112.81, max: 500)
#
# Run: 135, exploration: 0.01, score: 292
# Scores: (min: 13, avg: 115.32, max: 500)
#
# Run: 136, exploration: 0.01, score: 213
# Scores: (min: 13, avg: 117.21, max: 500)
#
# Run: 137, exploration: 0.01, score: 410
# Scores: (min: 13, avg: 121.02, max: 500)
#
# Run: 138, exploration: 0.01, score: 268
# Scores: (min: 13, avg: 123.46, max: 500)
#
# Run: 139, exploration: 0.01, score: 416
# Scores: (min: 13, avg: 127.41, max: 500)
#
# Run: 140, exploration: 0.01, score: 227
# Scores: (min: 13, avg: 129.52, max: 500)
#
# Run: 141, exploration: 0.01, score: 405
# Scores: (min: 13, avg: 133.41, max: 500)
#
# Run: 142, exploration: 0.01, score: 178
# Scores: (min: 13, avg: 135.05, max: 500)
#
# Run: 143, exploration: 0.01, score: 449
# Scores: (min: 13, avg: 139.36, max: 500)
#
# Run: 144, exploration: 0.01, score: 256
# Scores: (min: 13, avg: 141.64, max: 500)
#
# Run: 145, exploration: 0.01, score: 180
# Scores: (min: 13, avg: 143.17, max: 500)
#
# Run: 146, exploration: 0.01, score: 246
# Scores: (min: 13, avg: 145.47, max: 500)
#
# Run: 147, exploration: 0.01, score: 225
# Scores: (min: 13, avg: 147.57, max: 500)
#
# Run: 148, exploration: 0.01, score: 260
# Scores: (min: 13, avg: 149.99, max: 500)
#
# Run: 149, exploration: 0.01, score: 321
# Scores: (min: 13, avg: 152.88, max: 500)
#
# Run: 150, exploration: 0.01, score: 420
# Scores: (min: 13, avg: 156.9, max: 500)
#
# Run: 151, exploration: 0.01, score: 278
# Scores: (min: 13, avg: 159.55, max: 500)
#
# Run: 152, exploration: 0.01, score: 310
# Scores: (min: 19, avg: 162.52, max: 500)
#
# Run: 153, exploration: 0.01, score: 189
# Scores: (min: 20, avg: 164.22, max: 500)
#
# Run: 154, exploration: 0.01, score: 250
# Scores: (min: 26, avg: 166.52, max: 500)
#
# Run: 155, exploration: 0.01, score: 229
# Scores: (min: 26, avg: 168.46, max: 500)
#
# Run: 156, exploration: 0.01, score: 241
# Scores: (min: 27, avg: 170.61, max: 500)
#
# Run: 157, exploration: 0.01, score: 193
# Scores: (min: 27, avg: 172.27, max: 500)
#
# Run: 158, exploration: 0.01, score: 187
# Scores: (min: 29, avg: 173.87, max: 500)
#
# Run: 159, exploration: 0.01, score: 334
# Scores: (min: 29, avg: 176.7, max: 500)
#
# Run: 160, exploration: 0.01, score: 219
# Scores: (min: 29, avg: 178.3, max: 500)
#
# Run: 161, exploration: 0.01, score: 323
# Scores: (min: 29, avg: 181.2, max: 500)
#
# Run: 162, exploration: 0.01, score: 344
# Scores: (min: 29, avg: 184.11, max: 500)
#
# Run: 163, exploration: 0.01, score: 295
# Scores: (min: 31, avg: 186.77, max: 500)
#
# Run: 164, exploration: 0.01, score: 424
# Scores: (min: 31, avg: 190.3, max: 500)
#
# Run: 165, exploration: 0.01, score: 250
# Scores: (min: 31, avg: 192.28, max: 500)
#
# Run: 166, exploration: 0.01, score: 291
# Scores: (min: 31, avg: 194.88, max: 500)
#
# Run: 167, exploration: 0.01, score: 379
# Scores: (min: 31, avg: 198.01, max: 500)
#
# Solved in 67 runs, 167 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-88ee365f123f> in <module>
#       2
#       3 print("Running experiment with lower learning rate:", LEARNING_RATE)
# ----> 4 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# ## **Objective**
# This experiment tested **a significantly lower learning rate (`LEARNING_RATE = 0.0001`)**, prioritizing **stability over rapid learning**. The goal was to evaluate whether reducing the learning rate improves convergence and long-term performance.
#
# ## **Performance Overview**
# - **Total Runs:** 167
# - **Solved in:** 67 runs
# - **Learning Rate (`α`)**: Reduced from **0.001** to **0.0001**
# - **Score Progression:**
#   - **Minimum Score:** 8
#   - **Maximum Score:** 500
#   - **Final Average Score:** 198.01
#
# ---
#
# ## **Observations**
# ### **Early Learning Phase (Runs 1–20)**
# - **Slow learning curve**—performance **remained low** for a longer period.
# - **Minimal fluctuation in scores**, indicating stability but **delayed improvement**.
# - **Learning took longer compared to previous experiments**.
#
# ### **Mid-Learning Phase (Runs 21–80)**
# - **Gradual increase in scores** as the agent learned more stable policies.
# - **More consistent improvements in performance**, though slower than in **Experiment 2**.
# - **Took longer to reach the 100+ score range** compared to other experiments.
#
# ### **Late Learning Phase (Runs 81–167)**
# - **Stable and strong performance after 100 runs**.
# - **Achieved 500-point max score** and **final average score of ~198**.
# - **Higher stability and less erratic behavior** than in **Experiment 3 (Low GAMMA)**.
#
# ---
#
# ## **Key Takeaways**
# ### **How does a lower learning rate (`α = 0.0001`) affect training?**
# - **Greater stability**, leading to **less variance in scores** over time.
# - **Slower learning phase** but **better long-term generalization**.
# - **Requires more runs to reach high performance**, but ultimately **solves the environment efficiently**.
#
# ### **How does this compare to previous experiments?**
# | Metric | Exp. 1 (High Exp. Decay) | Exp. 2 (Low Exp. Decay) | Exp. 3 (Low GAMMA) | Exp. 4 (Low α) |
# |--------|------------------|------------------|------------------|------------------|
# | **Solved in** | 151 runs | **47 runs** | 64 runs | 67 runs |
# | **Max Score** | 500 | 500 | 500 | 500 |
# | **Final Avg. Score** | 197.41 | 196.15 | 195.06 | **198.01** |
# | **Learning Rate (`α`)** | 0.001 | 0.001 | 0.001 | **0.0001** |
# | **Exploration Rate (`ε`)** | Standard | **Lower decay** | Standard | Standard |
# | **Discount Factor (`γ`)** | 0.95 | 0.95 | **0.85** | 0.95 |

# %% [markdown]
# ----

# %% [markdown]
#  # Final Analysis: Comparing All Experiments
#
# This report consolidates findings from four experiments that tested different hyperparameters in a reinforcement learning model using the CartPole environment. The experiments focused on modifying the **discount factor (γ), exploration decay, learning rate, and other key parameters** to analyze their impact on training performance.
#
# ---
#
# ## **📊 Summary of Experiment Results**
# | **Experiment** | **Modified Parameter** | **Best Score** | **Avg. Score** | **Total Runs** | **Solved In** |
# |--------------|-----------------|-------------|------------|-------------|-----------|
# | **1️⃣ Higher Discount Factor (Long-Term Focus)** | γ = **0.99** | **500** | 210.75 | 143 | ✅ **Solved in 45 runs** |
# | **2️⃣ Low Exploration Decay (More Exploration)** | Exploration Decay = **0.95** | **500** | 161.77 | 147 | ✅ **Solved in 47 runs** |
# | **3️⃣ Lower Discount Factor (Short-Term Focus)** | γ = **0.85** | **500** | 193.55 | 164 | ✅ **Solved in 64 runs** |
# | **4️⃣ Lower Learning Rate (More Stability)** | Learning Rate = **0.0001** | **500** | 198.01 | 167 | ✅ **Solved in 67 runs** |
#
# 🔹 **Key Observations**:
# - **Higher Discount Factor (γ = 0.99) led to faster convergence** and achieved **higher long-term rewards**.
# - **Lower Exploration Decay (0.95) resulted in more exploration initially**, but took longer to stabilize.
# - **Lower Discount Factor (γ = 0.85) improved short-term gains** but underperformed long-term.
# - **Lower Learning Rate (0.0001) increased stability but slowed learning**.
#
# ---
#
# ## **📝 Experiment Insights & Key Takeaways**
#
# ### **1️⃣ Impact of Discount Factor (γ)**
# - A **higher discount factor (γ = 0.99)** encouraged the agent to optimize for **long-term rewards**, leading to **faster convergence**.
# - A **lower discount factor (γ = 0.85)** forced the agent to prioritize **short-term rewards**, leading to higher variance and slower improvement.
#
# **🔹 Conclusion:** High discount factors (**γ ≈ 0.99**) are ideal for reinforcement learning models **where long-term planning is critical**.
#
# ---
#
# ### **2️⃣ Impact of Exploration Decay**
# - **Lower Exploration Decay (0.95) led to extended exploration periods**, which **delayed convergence but resulted in better generalization**.
# - The agent required **more runs to stabilize** but performed well once exploration ended.
#
# **🔹 Conclusion:** Lower exploration decay is useful **when a diverse range of experiences is needed** before stabilizing the policy.
#
# ---
#
# ### **3️⃣ Impact of Learning Rate (α)**
# - **Lower Learning Rate (0.0001) improved stability** but **slowed down** learning significantly.
# - The agent avoided **catastrophic forgetting**, but it took **more runs** to achieve optimal performance.
#
# **🔹 Conclusion:** Lower learning rates are beneficial **when stability is preferred over fast convergence**.
#
# ---
#
# ### 3️⃣ **Impact of Experience Replay in the Cartpole Problem**
# Experience replay was instrumental in diversifying the agent’s training experiences by storing past transitions in a replay buffer and sampling them randomly during training. This process:
# - **Breaks correlations** between sequential experiences, preventing the model from overfitting to a specific sequence of states.
# - **Improves learning efficiency** by reusing past experiences multiple times.
# - Contributed to stabilization during training, particularly in experiments with low exploration decay and lower learning rates.
#
# 🔹 **Conclusion**: Experience replay is a critical component for enhancing training efficiency and generalization in reinforcement learning.
#
# ---
#
# ### 4️⃣ **Impact of Neural Networks in the Cartpole Problem**
# The neural network architecture used in the CartPole environment consisted of:
# - **Input Layer**: Encoded the state of the environment (e.g., cart position, velocity).
# - **Hidden Layers**: Included two fully connected layers with ReLU activation functions for feature extraction.
# - **Output Layer**: Predicted Q-values for possible actions (move left or right).
#
# The network was trained using:
# - **Loss Function**: Mean squared error (MSE) between predicted Q-values and target Q-values.
# - **Optimizer**: Adam optimizer for adaptive learning rates.
# - **Backpropagation**: Updated weights to minimize prediction errors and improve policy quality.
#
# 🔹 **Conclusion**: The neural network served as a critical decision-making component, leveraging deep learning to predict and optimize actions effectively in the CartPole environment.
#
# ---
#
# ## 📚 Citations
#
# - Beysolow, T. (2019). *Applied reinforcement learning with Python: With OpenAI Gym, TensorFlow, and Keras*. Apress.
# - freeCodeCamp. (n.d.). An introduction to Q-learning. *Medium*. https://medium.com/free-code-camp/an-introduction-to-q-learning-reinforcement-learning-14ac0b4493cc
# - Gulli, A., & Pal, S. (2017). *Deep learning with Keras: Implementing deep learning models and neural networks with the power of Python*. Packt Publishing.
# - Mnih, V., Kavukcuoglu, K., Silver, D., Rusu, A. A., et al. (2015). Human-level control through deep reinforcement learning. *Nature, 518*(7540), 529–533. https://doi.org/10.1038/nature14236
# - Silver, D., et al. (2017). Mastering chess and shogi by self-play with a general reinforcement learning algorithm. *arXiv preprint*.
# - Sutton, R. S., & Barto, A. G. (2018). *Reinforcement learning: An introduction* (2nd ed.). MIT Press.
#
#
# ---

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.
